# %% [markdown]
# # Exploratory Data Analysis for Greater London Authority

# %% [markdown]
# ## What are the demographics of cyclists?

# %% [markdown]
# ### Import Libraries

# %%
#Import the basic libraries
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import date

#Import the basic visualisations
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import DataSets

# %%
#Load the dataset
Central_London = pd.read_csv("Central London.csv")
Inner_London = pd.read_csv("Inner London.csv")
Outer_London = pd.read_csv("Outer London.csv")

# %% [markdown]
# ### Data Exploration

# %%
# How can I deliminate the data
# Understanding the shape and nature of the data
Central_London.head(2)
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN

# %%
Central_London.dtypes
# Out:
# Survey wave (calendar quarter)     object
# Equivalent financial quarter       object
# Site ID                            object
# Location                           object
# Survey date                        object
# Weather                            object
# Time                               object
# Period                             object
# Direction                          object
# Start hour                        float64
# Start minute                      float64
# Number of private cycles          float64
# Number of cycle hire bikes        float64
# Total cycles                      float64
# Unnamed: 14                       float64
# Unnamed: 15                       float64
# Unnamed: 16                       float64
# dtype: object

# %%
# Understanding the shape and nature of the data
Inner_London.head(2)
# Out:
#    Survey wave (year)   Site ID    Location    Survey date Weather  \
# 0              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 1              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
#
#           Time                       Period   Direction  Start hour  \
# 0  0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1  0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
#
#    Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0           0.0                       1.0                         0.0
# 1          15.0                       2.0                         0.0
#
#    Total cycles
# 0           1.0
# 1           2.0

# %%
# Understanding the shape and nature of the data
Outer_London.head(2)
# Out:
#    Survey wave (year)   Site ID          Location    Survey date Weather  \
# 0                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 1                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
#
#           Time                       Period   Direction  Start hour  \
# 0  0600 - 0615  Early Morning (06:00-07:00)  Northbound           6
# 1  0615 - 0630  Early Morning (06:00-07:00)  Northbound           6
#
#    Start minute  Number of male cycles  Number of female cycles  \
# 0             0                      2                        1
# 1            15                      3                        0
#
#    Number of unknown cycles  Total cycles
# 0                         0             3
# 1                         0             3

# %% [markdown]
# ### What is the sentiment towards cycling in London?

# %%
# copy the YAML file and your Twitter keys over before you start to work
# !pip install pyyaml
import yaml
from yaml.loader import SafeLoader
from twitter import *

# Import the yaml file - remember to specify the whole path and use / between directories
twitter_creds = yaml.safe_load(open('C://Users//Akira//Desktop//LSE//Python//twitter.yaml', 'r').read())

# pass your twitter credentials
twitter_api = Twitter(auth=OAuth(twitter_creds['access_token'],
                                 twitter_creds['access_token_secret'], 
                                 twitter_creds['api_key'],
                                 twitter_creds['api_secret_key'] ))
# Out:
# Requirement already satisfied: pyyaml in c:\users\akira\anaconda3\lib\site-packages (6.0)

# %%
print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x0000022838AF3D00>

# %% [markdown]
# # Run  a test

# %%
# Run a test with #cycling
cycling_tweets = twitter_api.search.tweets(q="#cycling")

# View output
print(cycling_tweets)
# Out:
# {'statuses': [{'created_at': 'Thu Aug 11 15:32:36 +0000 2022', 'id': 1557751847770898433, 'id_str': '1557751847770898433', 'text': 'Vittoria Targets Less Weight and Speed with New "Ultra Light Speed" Inner Tube @VittoriaTires #VittoriaTires… https://t.co/0onN3QqvZQ', 'truncated': True, 'entities': {'hashtags': [{'text': 'VittoriaTires', 'indices': [94, 108]}], 'symbols': [], 'user_mentions': [{'screen_name': 'VittoriaTires', 'name': 'Vittoria', 'id': 142718414, 'id_str': '142718414', 'indices': [79, 93]}], 'urls': [{'url': 'https://t.co/0onN3QqvZQ', 'expanded_url': 'https://twitter.com/i/web/status/1557751847770898433', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [110, 133]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://publicize.wp.com/" rel="nofollow">WordPress.com</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 618637104, 'id_str': '618637104', 'name': 'Capo Velo', 'screen_name': 'CapoVelo', 'location': 'United States ', 'description': 'Capo Velo Cycling Collective', 'url': 'http://t.co/RGzjQQVadQ', 'entities': {'url': {'urls': [{'url': 'http://t.co/RGzjQQVadQ', 'expanded_url': 'http://capovelo.com', 'display_url': 'capovelo.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1584, 'friends_count': 494, 'listed_count': 191, 'created_at': 'Tue Jun 26 00:08:31 +0000 2012', 'favourites_count': 6846, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 40353, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '3B94D9', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/3325457275/bf103bacee5474f52e5490f749a46a49_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3325457275/bf103bacee5474f52e5490f749a46a49_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/618637104/1430881605', 'profile_link_color': '3B94D9', 'profile_sidebar_border_color': 'F2E195', 'profile_sidebar_fill_color': 'FFF7CC', 'profile_text_color': '0C3E53', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, {'created_at': 'Thu Aug 11 15:32:11 +0000 2022', 'id': 1557751740149239811, 'id_str': '1557751740149239811', 'text': "I believe that banning 🇷🇺 innocent Russian athletes from foreign races won't stop the war.\n\nIt was already hard for… https://t.co/vtGzwufyKk", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/vtGzwufyKk', 'expanded_url': 'https://twitter.com/i/web/status/1557751740149239811', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1150131630687866880, 'id_str': '1150131630687866880', 'name': 'CyclingBottle', 'screen_name': 'Cyclingbottle', 'location': 'In the heart of cycling', 'description': 'The  ...

# %%
#Query the term 'cycling'
q = {'q': 'cycling', 'count':100, 'result_type':'recent'}

#Set results to an empty list
results = []

#Use a while loop and specify condition as len(results) < 30:
while len(results)<30:
    query=twitter_api.search.tweets(**q)
    q['max_id'] = query['search_metadata']['next_results'].split('&')[0].split('?max_id=')[1]
    results.append(query)
    
#Determine length of results
len(results)
# Out:
# 30

# %%
cycling_list_pd = pd.concat([pd.DataFrame(_['statuses']) for _ in results])

# View shape of output
cycling_list_pd.shape
# Out:
# (3000, 30)

# %%
cycling_list_pd.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Thu Aug 11 15:33:41 +0000 2022  1557752119171526657  1557752119171526657
# 1  Thu Aug 11 15:33:37 +0000 2022  1557752100918071302  1557752100918071302
# 2  Thu Aug 11 15:33:34 +0000 2022  1557752091245916161  1557752091245916161
# 3  Thu Aug 11 15:33:30 +0000 2022  1557752074703900672  1557752074703900672
# 4  Thu Aug 11 15:33:11 +0000 2022  1557751991794810880  1557751991794810880
#
#                                                 text  truncated  \
# 0  RT @Mamethebirb: [ลดน้ำหนัก] โยโย่ คืออะไร เกิ...      False
# 1  Climate Action Preston’s cycling project launc...       True
# 2  Cycling or biking in Kansas, instead of guzzli...       True
# 3  RT @Mamethebirb: [ลดน้ำหนัก] โยโย่ คืออะไร เกิ...      False
# 4  RT @travelmail: Glamping with grandparents? Ch...      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'th', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'th', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/iphone" r...                    NaN
# 1  <a href="https://mobile.twitter.com" rel="nofo...           1.557752e+18
# 2  <a href="https://cheapbotsdonequick.com" rel="...                    NaN
# 3  <a href="http://twitter.com/download/android" ...                    NaN
# 4  <a href="https://www.make.com" rel="nofollow">...                    NaN
#
#   in_reply_to_status_id_str  ...  retweet_count favorite_count favorited  \
# 0                      None  ...           4250              0     False
# 1       1557751942721552386  ...              0              0     False
# 2                      None  ...              0              0     False
# 3                      None  ...           4250              0     False
# 4                      None  ...              2              0     False
#
#   retweeted lang quoted_status_id quoted_status_id_str possibly_sensitive  \
# 0     False   th              NaN                  NaN                NaN
# 1     False   en              NaN                  NaN                NaN
# 2     False   en              NaN                  NaN                NaN
# 3     False   th              NaN                  NaN                NaN
# 4     False   en              NaN                  NaN                NaN
#
#   quoted_status  extended_entities
# 0           NaN                NaN
# 1           NaN                NaN
# 2           NaN                NaN
# 3           NaN                NaN
# 4           NaN                NaN
#
# [5 rows x 30 columns]

# %%
#Exploring extracted twitter data
cycling_list_pd.dtypes
# Out:
# created_at                    object
# id                             int64
# id_str                        object
# text                          object
# truncated                       bool
# entities                      object
# metadata                      object
# source                        object
# in_reply_to_status_id        float64
# in_reply_to_status_id_str     object
# in_reply_to_user_id          float64
# in_reply_to_user_id_str       object
# in_reply_to_screen_name       object
# user                          object
# geo                           object
# coordinates                   object
# place                         object
# contributors                  object
# retweeted_status              object
# is_quote_status                 bool
# retweet_count                  int64
# favorite_count                 int64
# favorited                       bool
# retweeted                       bool
# lang                          object
# quoted_status_id             float64
# quoted_status_id_str          object
# possibly_sensitive            object
# quoted_status                 object
# extended_entities             object
# dtype: object

# %%
#Converting column from object to text
cycling_list_values = cycling_list_pd['text'].values

# %%
#Visualise tweet example
cycling_list_values[2]
# Out:
# "Cycling or biking in Kansas, instead of guzzling gas in a car, will immensely lessen emissions, let's get better to… https://t.co/BlTbxXfTo3"

# %% [markdown]
# # DETERMINING TRENDING TWITTER TOPICS IN LONDON

# %%
# determine worldwide trends
trends_worldwide = twitter_api.trends.available()

# how many trends available
print(len(trends_worldwide))

# example of trends_worldwide
trends_worldwide[0]
# Out:
# 467
# {'name': 'Worldwide',
#  'placeType': {'code': 19, 'name': 'Supername'},
#  'url': 'http://where.yahooapis.com/v1/place/1',
#  'parentid': 0,
#  'country': '',
#  'woeid': 1,
#  'countryCode': None}

# %%
# write a twitter request
list_of_names = [_['name'] for _ in trends_worldwide]

# list of first 10
list_of_names[0:10]
# Out:
# ['Worldwide',
#  'Winnipeg',
#  'Ottawa',
#  'Quebec',
#  'Montreal',
#  'Toronto',
#  'Edmonton',
#  'Calgary',
#  'Vancouver',
#  'Birmingham']

# %%
# find Melbourne
our_city = 'London'

# create variable
list_of_names_our_city = [_ for _ in trends_worldwide if _['name'] == our_city]

# view output
print(len(list_of_names_our_city))

# use index to find Melbourne
list_of_names_our_city[0]
# Out:
# 1
# {'name': 'London',
#  'placeType': {'code': 7, 'name': 'Town'},
#  'url': 'http://where.yahooapis.com/v1/place/44418',
#  'parentid': 23424975,
#  'country': 'United Kingdom',
#  'woeid': 44418,
#  'countryCode': 'GB'}

# %%
# list of where on earth identifies (woeid)
list_of_names_our_city[0]['woeid']
# Out:
# 44418

# %%
# look at trends in Melbourne
london_trends = twitter_api.trends.place(_id = list_of_names_our_city[0]['woeid'])

# view output
london_trends
# Out:
# [{'trends': [{'name': '#AONArsenal',
#     'url': 'http://twitter.com/search?q=%23AONArsenal',
#     'promoted_content': None,
#     'query': '%23AONArsenal',
#     'tweet_volume': None},
#    {'name': '#wato',
#     'url': 'http://twitter.com/search?q=%23wato',
#     'promoted_content': None,
#     'query': '%23wato',
#     'tweet_volume': None},
#    {'name': '#energybills',
#     'url': 'http://twitter.com/search?q=%23energybills',
#     'promoted_content': None,
#     'query': '%23energybills',
#     'tweet_volume': None},
#    {'name': 'Joshua',
#     'url': 'http://twitter.com/search?q=Joshua',
#     'promoted_content': None,
#     'query': 'Joshua',
#     'tweet_volume': 89726},
#    {'name': '#DentistFilmsOrSongs',
#     'url': 'http://twitter.com/search?q=%23DentistFilmsOrSongs',
#     'promoted_content': None,
#     'query': '%23DentistFilmsOrSongs',
#     'tweet_volume': None},
#    {'name': 'JEON JUNGKOOK',
#     'url': 'http://twitter.com/search?q=%22JEON+JUNGKOOK%22',
#     'promoted_content': None,
#     'query': '%22JEON+JUNGKOOK%22',
#     'tweet_volume': 45889},
#    {'name': '#heatwave',
#     'url': 'http://twitter.com/search?q=%23heatwave',
#     'promoted_content': None,
#     'query': '%23heatwave',
#     'tweet_volume': 16698},
#    {'name': 'Rage Against The Machine',
#     'url': 'http://twitter.com/search?q=%22Rage+Against+The+Machine%22',
#     'promoted_content': None,
#     'query': '%22Rage+Against+The+Machine%22',
#     'tweet_volume': None},
#    {'name': 'Urged',
#     'url': 'http://twitter.com/search?q=Urged',
#     'promoted_content': None,
#     'query': 'Urged',
#     'tweet_volume': 11286},
#    {'name': 'RATM',
#     'url': 'http://twitter.com/search?q=RATM',
#     'promoted_content': None,
#     'query': 'RATM',
#     'tweet_volume': None},
#    {'name': 'Tommy Lee',
#     'url': 'http://twitter.com/search?q=%22Tommy+Lee%22',
#     'promoted_content': None,
#     'query': '%22Tommy+Lee%22',
#     'tweet_volume': None},
#    {'name': 'Buatsi',
#     'url': 'http://twitter.com/search?q=Buatsi',
#     'promoted_content': None,
#     'query': 'Buatsi',
#     'tweet_volume': None},
#    {'name': 'Kofi',
#     'url': 'http://twitter.com/search?q=Kofi',
#     'promoted_content': None,
#     'query': 'Kofi',
#     'tweet_volume': 16134},
#    {'name': 'Nuala',
#     'url': 'http://twitter.com/search?q=Nuala',
#     'promoted_content': None,
#     'query': 'Nuala',
#     'tweet_volume': None},
#    {'name': 'Tavistock',
#     'url': 'http://twitter.com/search?q=Tavistock',
#     'promoted_content': None,
#     'query': 'Tavistock',
#     'tweet_volume': 14315},
#    {'name': 'Andrew Tate',
#     'url': 'http://twitter.com/search?q=%22Andrew+Tate%22',
#     'promoted_content': None,
#     'query': '%22Andrew+Tate%22',
#     'tweet_volume': 28503},
#    {'name': 'Modric',
#     'url': 'http://twitter.com/search?q=Modric',
#     'promoted_content': None,
#     'query': 'Modric',
#     'tweet_volume': 23043},
#    {'name': 'Martin Lewis',
#     'url': 'http://twitter.com/search?q=%22Martin+Lewis%22',
#     'promoted_content': None,
#     'query': '%22Martin+Lewis%22',
#     'tweet_volume': 26265},
#    {'name': 'Harvey Elliott',
#     'url': 'http://twitter.com/search?q=%22Harvey+Elliott%22',
#     'promoted_content': None,
#     'query': '%22Harvey+Elliott%22',
#     'tweet_volume': None},
#    {'name': 'Tower of Fantasy',
#     'url': 'http://twitter.com/search?q=%22Tower+of+Fantasy%22',
#     'promoted_content': None,
#     'query': '%22Tower+of+Fantasy%22',
#     'tweet_volume': 51545},
#    {'name': 'Pascal',
#     'url': 'http://twitter.com/search?q=Pascal',
#     'promoted_content': None,
#     'query': 'Pascal',
#     'tweet_volume': 10874},
#    {'name': 'MAPs',
#     'url': 'http://twitter.com/search?q=MAPs',
#     'promoted_content': None,
#     'query': 'MAPs',
#     'tweet_volume': 67074},
#    {'name': 'Vogue',
#     'url': 'http://twitter.com/search?q=Vogue',
#     'promoted_content': None,
#     'query': 'Vogue',
#     'tweet_volume': 23547},
#    {'name': 'Dan Hodges',
#     'url': 'http://twitter.com/search?q=%22Dan+Hodges%22',
#     'promoted_content': None,
#     'query': '%22Dan+Hodges%22',
#     'tweet_volume': None},
#    {'name': 'Britney',
#     'url': 'http://twitter.com/search?q=Britney',
#     'promoted_content': None,
#     'query': 'Britney',
#     'tweet_volume': 52789},
#    {'name': 'Eddie Izzard',
#     'url': 'http://twitter.com/search?q=%22Eddie+Izzard%22',
#     'promoted_content': None,
#     'query': '%22Eddie+Izzard%22',
#     'tweet_volume': None},
#    {'name': 'Willian',
#     'url': 'http://twitter.com/search?q=Willian',
#     'promoted_content': None,
#     'query': 'Willian',
#     'tweet_volume': 17143},
#    {'name': 'Eventbrite',
#     'url': 'http://twitter.com/search?q=Eventbrite',
#     'promoted_content': None,
#     'query': 'Eventbrite',
#     'tweet_volume': 15921},
#    {'name': 'Kevin Federline',
#     'url': 'http://twitter.com/search?q=%22Kevin+Federline%22',
#     'promoted_content': None,
#     'query': '%22Kevin+Federline%22',
#     'tweet_volume': 17298},
#    {'name': 'mermaids',
#     'url': 'http://twitter.com/search?q=mermaids',
#     'promoted_content': None,
#     'query': 'mermaids',
#     'tweet_volume': None},
#    {'name': 'Ryanair',
#     'url': 'http://twitter.com/search?q=Ryanair',
#     'promoted_content': None,
#     'query': 'Ryanair',
#     'tweet_volume': None},
#    {'name': 'Mark Spencer',
#     'url': 'http://twitter.com/search?q=%22Mark+Spencer%22',
#     'promoted_content': None,
#     'query': '%22Mark+Spencer%22',
#     'tweet_volume': None},
#    {'name': 'Eddie Mair',
#     'url': 'http://twitter.com/search?q=%22Eddie+Mair%22',
#     'promoted_content': None,
#     'query': '%22Eddie+Mair%22',
#     'tweet_volume': None},
#    {'name': 'alex salmond',
#     'url': 'http://twitter.com/search?q=%22alex+salmond%22',
#     'promoted_content': None,
#     'query': '%22alex+salmond%22',
#     'tweet_volume': None},
#    {'name': 'Ramos',
#     'url': 'http://twitter.com/search?q=Ramos',
#     'promoted_content': None,
#     'query': 'Ramos',
#     'tweet_volume': 28765},
#    {'name': '#thursdayvibes',
#     'url': 'http://twitter.com/search?q=%23thursdayvibes',
#     'promoted_content': None,
#     'query': '%23thursdayvibes',
#     'tweet_volume': 14294},
#    {'name': '#ShowUsYouKnowUs',
#     'url': 'http://twitter.com/search?q=%23ShowUsYouKnowUs',
#     'promoted_content': None,
#     'query': '%23ShowUsYouKnowUs',
#     'tweet_volume': None},
#    {'name': '#KeirStarmerInFiveWords',
#     'url': 'http://twitter.com/search?q=%23KeirStarmerInFiveWords',
#     'promoted_content': None,
#     'query': '%23KeirStarmerInFiveWords',
#     'tweet_volume': None},
#    {'name': '#CorbynWasRight',
#     'url': 'http://twitter.com/search?q=%23CorbynWasRight',
#     'promoted_content': None,
#     'query': '%23CorbynWasRight',
#     'tweet_volume': None},
#    {'name': '#anywherecard',
#     'url': 'http://twitter.com/search?q=%23anywherecard',
#     'promoted_content': None,
#     'query': '%23anywherecard',
#     'tweet_volume': None},
#    {'name': '#ClimateScam',
#     'url': 'http://twitter.com/search?q=%23ClimateScam',
#     'promoted_content': None,
#     'query': '%23ClimateScam',
#     'tweet_volume': None},
#    {'name': '#REVB',
#     'url': 'http://twitter.com/search?q=%23REVB',
#     'promoted_content': None,
#     'query': '%23REVB',
#     'tweet_volume': None},
#    {'name': '#RHOBH',
#     'url': 'http://twitter.com/search?q=%23RHOBH',
#     'promoted_content': None,
#     'query': '%23RHOBH',
#     'tweet_volume': 24176},
#    {'name': '#ThursdayThoughts',
#     'url': 'http://twitter.com/search?q=%23ThursdayThoughts',
#     'promoted_content': None,
#     'query': '%23ThursdayThoughts',
#     'tweet_volume': None},
#    {'name': '#aplaceinthesun',
#     'url': 'http://twitter.com/search?q=%23aplaceinthesun',
#     'promoted_content': None,
#     'query': '%23aplaceinthesun',
#     'tweet_volume': None},
#    {'name': '#CheltLitFest',
#     'url': 'http://twitter.com/search?q=%23CheltLitFest',
#     'promoted_content': None,
#     'query': '%23CheltLitFest',
#     'tweet_volume': None},
#    {'name': '#RakshaBandhan',
#     'url': 'http://twitter.com/search?q=%23RakshaBandhan',
#     'promoted_content': None,
#     'query': '%23RakshaBandhan',
#     'tweet_volume': 307425},
#    {'name': '#FIFA23',
#     'url': 'http://twitter.com/search?q=%23FIFA23',
#     'promoted_content': None,
#     'query': '%23FIFA23',
#     'tweet_volume': 23393},
#    {'name': '#hiring',
#     'url': 'http://twitter.com/search?q=%23hiring',
#     'promoted_content': None,
#     'query': '%23hiring',
#     'tweet_volume': 14416},
#    {'name': '#Somaliland',
#     'url': 'http://twitter.com/search?q=%23Somaliland',
#     'promoted_content': None,
#     'query': '%23Somaliland',
#     'tweet_volume': None}],
#   'as_of': '2022-08-11T15:43:30Z',
#   'created_at': '2022-07-26T16:50:00Z',
#   'locations': [{'name': 'London', 'woeid': 44418}]}]

# %%
#CREATE A DATAFRAME FOR LONDON CITY TRENDS
# create DataFrame
london_trends_pd = pd.DataFrame(our_city_trends[0]['trends'])

# view DataFrame
london_trends_pd
# Out:
#                        name  \
# 0               #AONArsenal
# 1                     #wato
# 2              #energybills
# 3                   #NFTiff
# 4                    Joshua
# 5               Jeremy Kyle
# 6                     Bowie
# 7                     Urged
# 8                    Buatsi
# 9                 Tommy Lee
# 10                     Rage
# 11                     RATM
# 12                     Kofi
# 13                    Nuala
# 14                Tavistock
# 15           Harvey Elliott
# 16                   Modric
# 17             Martin Lewis
# 18              Andrew Tate
# 19                   Pascal
# 20                     MAPs
# 21                    Vogue
# 22         Tower of Fantasy
# 23               Dan Hodges
# 24                  Britney
# 25                 Atalanta
# 26             Eddie Izzard
# 27                  Willian
# 28               Eventbrite
# 29          Kevin Federline
# 30                 Mermaids
# 31                  Ryanair
# 32             Mark Spencer
# 33               Eddie Mair
# 34                     Cass
# 35             Alex Salmond
# 36                    Ramos
# 37                 #drought
# 38     #DentistFilmsOrSongs
# 39                #heatwave
# 40           #thursdayvibes
# 41         #ShowUsYouKnowUs
# 42          #CorbynWasRight
# 43             #ClimateScam
# 44            #anywherecard
# 45  #KeirStarmerInFiveWords
# 46                    #REVB
# 47                   #RHOBH
#
#                                                   url promoted_content  \
# 0           http://twitter.com/search?q=%23AONArsenal             None
# 1                 http://twitter.com/search?q=%23wato             None
# 2          http://twitter.com/search?q=%23energybills             None
# 3               http://twitter.com/search?q=%23NFTiff             None
# 4                  http://twitter.com/search?q=Joshua             None
# 5       http://twitter.com/search?q=%22Jeremy+Kyle%22             None
# 6                   http://twitter.com/search?q=Bowie             None
# 7                   http://twitter.com/search?q=Urged             None
# 8                  http://twitter.com/search?q=Buatsi             None
# 9         http://twitter.com/search?q=%22Tommy+Lee%22             None
# 10                   http://twitter.com/search?q=Rage             None
# 11                   http://twitter.com/search?q=RATM             None
# 12                   http://twitter.com/search?q=Kofi             None
# 13                  http://twitter.com/search?q=Nuala             None
# 14              http://twitter.com/search?q=Tavistock             None
# 15   http://twitter.com/search?q=%22Harvey+Elliott%22             None
# 16                 http://twitter.com/search?q=Modric             None
# 17     http://twitter.com/search?q=%22Martin+Lewis%22             None
# 18      http://twitter.com/search?q=%22Andrew+Tate%22             None
# 19                 http://twitter.com/search?q=Pascal             None
# 20                   http://twitter.com/search?q=MAPs             None
# 21                  http://twitter.com/search?q=Vogue             None
# 22  http://twitter.com/search?q=%22Tower+of+Fantas...             None
# 23       http://twitter.com/search?q=%22Dan+Hodges%22             None
# 24                http://twitter.com/search?q=Britney             None
# 25               http://twitter.com/search?q=Atalanta             None
# 26     http://twitter.com/search?q=%22Eddie+Izzard%22             None
# 27                http://twitter.com/search?q=Willian             None
# 28             http://twitter.com/search?q=Eventbrite             None
# 29  http://twitter.com/search?q=%22Kevin+Federline%22             None
# 30               http://twitter.com/search?q=Mermaids             None
# 31                http://twitter.com/search?q=Ryanair             None
# 32     http://twitter.com/search?q=%22Mark+Spencer%22             None
# 33       http://twitter.com/search?q=%22Eddie+Mair%22             None
# 34                   http://twitter.com/search?q=Cass             None
# 35     http://twitter.com/search?q=%22Alex+Salmond%22             None
# 36                  http://twitter.com/search?q=Ramos             None
# 37             http://twitter.com/search?q=%23drought             None
# 38  http://twitter.com/search?q=%23DentistFilmsOrS...             None
# 39            http://twitter.com/search?q=%23heatwave             None
# 40       http://twitter.com/search?q=%23thursdayvibes             None
# 41     http://twitter.com/search?q=%23ShowUsYouKnowUs             None
# 42      http://twitter.com/search?q=%23CorbynWasRight             None
# 43         http://twitter.com/search?q=%23ClimateScam             None
# 44        http://twitter.com/search?q=%23anywherecard             None
# 45  http://twitter.com/search?q=%23KeirStarmerInFi...             None
# 46                http://twitter.com/search?q=%23REVB             None
# 47               http://twitter.com/search?q=%23RHOBH             None
#
#                         query  tweet_volume
# 0               %23AONArsenal           NaN
# 1                     %23wato           NaN
# 2              %23energybills           NaN
# 3                   %23NFTiff       15774.0
# 4                      Joshua       89369.0
# 5           %22Jeremy+Kyle%22           NaN
# 6                       Bowie           NaN
# 7                       Urged       11171.0
# 8                      Buatsi           NaN
# 9             %22Tommy+Lee%22           NaN
# 10                       Rage       47077.0
# 11                       RATM           NaN
# 12                       Kofi       15862.0
# 13                      Nuala           NaN
# 14                  Tavistock       14222.0
# 15       %22Harvey+Elliott%22           NaN
# 16                     Modric       22960.0
# 17         %22Martin+Lewis%22       26064.0
# 18          %22Andrew+Tate%22       28216.0
# 19                     Pascal       10795.0
# 20                       MAPs       66511.0
# 21                      Vogue       23399.0
# 22     %22Tower+of+Fantasy%22       51208.0
# 23           %22Dan+Hodges%22           NaN
# 24                    Britney       52254.0
# 25                   Atalanta           NaN
# 26         %22Eddie+Izzard%22           NaN
# 27                    Willian       17079.0
# 28                 Eventbrite       15817.0
# 29      %22Kevin+Federline%22       17041.0
# 30                   Mermaids           NaN
# 31                    Ryanair           NaN
# 32         %22Mark+Spencer%22           NaN
# 33           %22Eddie+Mair%22           NaN
# 34                       Cass           NaN
# 35         %22Alex+Salmond%22           NaN
# 36                      Ramos       28570.0
# 37                 %23drought       11726.0
# 38     %23DentistFilmsOrSongs           NaN
# 39                %23heatwave       16473.0
# 40           %23thursdayvibes       14044.0
# 41         %23ShowUsYouKnowUs           NaN
# 42          %23CorbynWasRight           NaN
# 43             %23ClimateScam           NaN
# 44            %23anywherecard           NaN
# 45  %23KeirStarmerInFiveWords           NaN
# 46                    %23REVB           NaN
# 47                   %23RHOBH       24018.0

# %%
london_trends_lists = [trend['name'] for trend in london_trends[0]['trends']]

#view output
print(london_trends_lists)
# Out:
# ['#AONArsenal', '#wato', '#energybills', 'Joshua', '#DentistFilmsOrSongs', 'JEON JUNGKOOK', '#heatwave', 'Rage Against The Machine', 'Urged', 'RATM', 'Tommy Lee', 'Buatsi', 'Kofi', 'Nuala', 'Tavistock', 'Andrew Tate', 'Modric', 'Martin Lewis', 'Harvey Elliott', 'Tower of Fantasy', 'Pascal', 'MAPs', 'Vogue', 'Dan Hodges', 'Britney', 'Eddie Izzard', 'Willian', 'Eventbrite', 'Kevin Federline', 'mermaids', 'Ryanair', 'Mark Spencer', 'Eddie Mair', 'alex salmond', 'Ramos', '#thursdayvibes', '#ShowUsYouKnowUs', '#KeirStarmerInFiveWords', '#CorbynWasRight', '#anywherecard', '#ClimateScam', '#REVB', '#RHOBH', '#ThursdayThoughts', '#aplaceinthesun', '#CheltLitFest', '#RakshaBandhan', '#FIFA23', '#hiring', '#Somaliland']

# %% [markdown]
# # Perform Sentiment Analysis on Tweets

# %%
#import SentimentIntensityAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#create a variable to store SIA
cycle_london = SentimentIntensityAnalyzer()

# %%
#Run dict comprehension 
cycling_list_values_token_nostop_polarity =\
{" ".join(_) : cycle_london.polarity_scores(" ".join(_)) for _ in cycling_list_values_token}

# %%
#Create a polarity DataFrame
polarity_pd = pd.DataFrame(cycling_list_values_token_nostop_polarity).T

# %%
#Top 20 most positive cycling tweets
polarity_pd.sort_values('pos', ascending=0).head(20)
# Out:
#                                                     neg    neu    pos  \
# Out cycling listening to @ thevaughnsnj & gt ; ...  0.0  0.469  0.531
# @ cyclist_andyc Well done to all of you , compl...  0.0  0.493  0.507
# RT @ WeRideAustralia : Fiona Campbell won a 201...  0.0  0.496  0.504
# @ ljhamilton88 Yes ! What a great way to spend ...  0.0  0.497  0.503
# # ADCC is very proud to share this great achiev...  0.0  0.504  0.496
# # ADCC is very proud to share this great achiev...  0.0  0.504  0.496
# Simple pleasures ; brilliant company , great we...  0.0  0.507  0.493
# New # cycling top . Olympique Marseille support...  0.0  0.515  0.485
# @ ExoHoranghae going cycling with jeonghan & am...  0.0  0.517  0.483
# @ feastsandfables @ WinningSolo Inching closer ...  0.0  0.539  0.461
# RT @ PuffaJones : Thank you to @ WelshBish for ...  0.0  0.541  0.459
# RT @ kathangus : Cycling in Brisbane is safe an...  0.0  0.552  0.448
# RT @ aerikyll : @ ExoHoranghae going cycling wi...  0.0  0.556  0.444
# RT @ HosniehMarbini : “ For me , having a bike ...  0.0  0.568  0.432
# @ cycling_dave That 's seriously impressive ! A...  0.1  0.470  0.431
# RT @ HappyDays_UK : Huge thank you @ jcaenginee...  0.0  0.573  0.427
# Mañana hago cycling wiii                            0.0  0.577  0.423
# 📂 Cyclescheme └ 📂 Love to Ride └ 📂 Photo Galler...  0.0  0.582  0.418
# Super spin up to work this morning , cycling in...  0.0  0.585  0.415
# With leadership like this , @ wutrain is winnin...  0.0  0.585  0.415
#
#                                                     compound
# Out cycling listening to @ thevaughnsnj & gt ; ...    0.8934
# @ cyclist_andyc Well done to all of you , compl...    0.9246
# RT @ WeRideAustralia : Fiona Campbell won a 201...    0.9217
# @ ljhamilton88 Yes ! What a great way to spend ...    0.7959
# # ADCC is very proud to share this great achiev...    0.9567
# # ADCC is very proud to share this great achiev...    0.9567
# Simple pleasures ; brilliant company , great we...    0.9393
# New # cycling top . Olympique Marseille support...    0.9042
# @ ExoHoranghae going cycling with jeonghan & am...    0.9042
# @ feastsandfables @ WinningSolo Inching closer ...    0.8203
# RT @ PuffaJones : Thank you to @ WelshBish for ...    0.9357
# RT @ kathangus : Cycling in Brisbane is safe an...    0.7964
# RT @ aerikyll : @ ExoHoranghae going cycling wi...    0.9042
# RT @ HosniehMarbini : “ For me , having a bike ...    0.9287
# @ cycling_dave That 's seriously impressive ! A...    0.7672
# RT @ HappyDays_UK : Huge thank you @ jcaenginee...    0.9080
# Mañana hago cycling wiii                              0.2960
# 📂 Cyclescheme └ 📂 Love to Ride └ 📂 Photo Galler...    0.9042
# Super spin up to work this morning , cycling in...    0.9422
# With leadership like this , @ wutrain is winnin...    0.9016

# %%
#Top 20 most negative cycling tweets
polarity_pd.sort_values('neg', ascending=0).head(20)
# Out:
#                                                       neg    neu    pos  \
# Todays Ridiculous Anti- or more appropriately S...  0.515  0.485  0.000
# Michele Gazzoli receives one-year ban for Anti-...  0.459  0.541  0.000
# @ AshCh1888 @ comcab33 You 're very aggressive ...  0.417  0.467  0.116
# cycling with broken glasses in a highway i love...  0.414  0.318  0.268
# i fucking hate cycling i am sweating SO MUCH        0.400  0.600  0.000
# @ phil_b @ gnomeicide @ cycling_dave I block pe...  0.398  0.602  0.000
# @ writebikerepeat America Fuck Yeah Cycling ( I...  0.397  0.459  0.144
# @ anewcd Die Standartrunde die ich immer noch f...  0.394  0.606  0.000
# Government to crack down on “ reckless ” riders...  0.393  0.607  0.000
# @ TheShickle Anyone who causes death by dangero...  0.389  0.611  0.000
# . @ grantshapps Two more dead and another famil...  0.375  0.625  0.000
# USA Cycling points to waiver to defeat lawsuit ...  0.365  0.481  0.154
# @ neilchristiex @ carltonreid Nah . Driving tak...  0.359  0.641  0.000
# Criminal justice system “ not fit for purpose ,...  0.359  0.522  0.118
# @ Enduracer79 @ 161_cycling oder die anderen ne...  0.358  0.642  0.000
# @ PlasticPlanners yes , I 've already blocked t...  0.342  0.558  0.100
# cycling with sando no bra owshii heaaaven ! ! ! 🥰   0.339  0.661  0.000
# RT @ PRODefSrinagar : ‘ Siachen War Memorial to...  0.338  0.662  0.000
# RT @ WeAreCyclingUK : Transport Secretary , Gra...  0.332  0.578  0.090
# RT @ roadcc : Criminal justice system “ not fit...  0.325  0.568  0.107
#
#                                                     compound
# Todays Ridiculous Anti- or more appropriately S...   -0.8166
# Michele Gazzoli receives one-year ban for Anti-...   -0.7783
# @ AshCh1888 @ comcab33 You 're very aggressive ...   -0.8414
# cycling with broken glasses in a highway i love...   -0.3182
# i fucking hate cycling i am sweating SO MUCH         -0.6115
# @ phil_b @ gnomeicide @ cycling_dave I block pe...   -0.8720
# @ writebikerepeat America Fuck Yeah Cycling ( I...   -0.5932
# @ anewcd Die Standartrunde die ich immer noch f...   -0.8316
# Government to crack down on “ reckless ” riders...   -0.8658
# @ TheShickle Anyone who causes death by dangero...   -0.8807
# . @ grantshapps Two more dead and another famil...   -0.8955
# USA Cycling points to waiver to defeat lawsuit ...   -0.5267
# @ neilchristiex @ carltonreid Nah . Driving tak...   -0.7814
# Criminal justice system “ not fit for purpose ,...   -0.7105
# @ Enduracer79 @ 161_cycling oder die anderen ne...   -0.5994
# @ PlasticPlanners yes , I 've already blocked t...   -0.7578
# cycling with sando no bra owshii heaaaven ! ! ! 🥰    -0.4724
# RT @ PRODefSrinagar : ‘ Siachen War Memorial to...   -0.8481
# RT @ WeAreCyclingUK : Transport Secretary , Gra...   -0.7717
# RT @ roadcc : Criminal justice system “ not fit...   -0.7105

# %%
polarity_pd['compound'].describe()
# Out:
# count    1774.000000
# mean        0.148920
# std         0.376699
# min        -0.895500
# 25%         0.000000
# 50%         0.000000
# 75%         0.440400
# max         0.956700
# Name: compound, dtype: float64

# %%
#Plot a boxplot
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import figure
import seaborn as sns

# %%
_plot = polarity_pd.reset_index()['compound'].sort_values()
_plot.plot(kind='box')
plt.title('Compound Polarity Score')

plt.savefig('Twitter Polarity Score.png')
# Out:
# Text(0.5, 1.0, 'Compound Polarity Score')

# %%
#Create a histogram of polarity for me to read and interpret

num_bins = 25
plt.figure(figsize=(16,9))

# Define the bars.
n, bins, patches = plt.hist(polarity_pd['compound'], num_bins, facecolor='red', alpha=0.6)
# Set the labels.
plt.xlabel('Polarity', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Sentiment score polarity', fontsize=20)

plt.savefig('Sentiment Score Polarity.png')
# Out:
# Text(0.5, 1.0, 'Sentiment score polarity')
