# %% [markdown]
# # Employer Project - Cycling in London
# ## Q2: Do people have a preference for private cycles vs cycle hires?

# %% [markdown]
# ### Import & Clean dataset

# %%
# Import necessary packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Directory
# !pwd
# Out:
# /Users/hazel/Documents/LSE Data Analytics/Employer Project/LSE_DA_Employer_Project_2_London

# %%
dir = "/Users/hazel/Documents/LSE Data Analytics/Employer Project/LSE_DA_Employer_Project_2_London"

# %%
# Load dataset
central_df = pd.read_csv(dir + "/London/Central London.csv")
inner_df = pd.read_csv(dir + "/London/Inner London.csv")
outer_df = pd.read_csv(dir + "/London/Outer London.csv")
# Out:
# /var/folders/b5/n0_mdqc51jl9_l242hqtgws00000gn/T/ipykernel_40138/1609253970.py:2: DtypeWarning: Columns (0,1,2,3,4,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   central_df = pd.read_csv(dir + "/London/Central London.csv")
# /var/folders/b5/n0_mdqc51jl9_l242hqtgws00000gn/T/ipykernel_40138/1609253970.py:3: DtypeWarning: Columns (1,2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   inner_df = pd.read_csv(dir + "/London/Inner London.csv")

# %% [markdown]
# ## Central London

# %%
# Add new column
central_df['Area'] = 'Central'

# %%
# View df
central_df.head()
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# ...

# %%
# View data types
central_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048366 entries, 0 to 1048365
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Survey wave (calendar quarter)  758163 non-null   object
#  1   Equivalent financial quarter    758163 non-null   object
#  2   Site ID                         758163 non-null   object
#  3   Location                        758163 non-null   object
#  4   Survey date                     748007 non-null   object
#  5   Weather                         746329 non-null   object
#  6   Time                            758163 non-null   object
#  7   Period                          758163 non-null   object
#  8   Direction                       758163 non-null   object
#  9   Start hour                      758163 non-null   float64
#  10  Start minute                    758163 non-null   float64
# ...

# %%
# Identify missing values
central_df.isna().sum()
# Out:
# Survey wave (calendar quarter)     290203
# Equivalent financial quarter       290203
# Site ID                            290203
# Location                           290203
# Survey date                        300359
# Weather                            302037
# Time                               290203
# Period                             290203
# Direction                          290203
# Start hour                         290203
# Start minute                       290203
# Number of private cycles           290267
# Number of cycle hire bikes         290267
# Total cycles                       290203
# Unnamed: 14                       1048366
# Unnamed: 15                       1048366
# Unnamed: 16                       1048366
# Area                                    0
# dtype: int64

# %%
# Explore
central_df.describe().round()
# Out:
#        Start hour  Start minute  Number of private cycles  \
# count    758163.0      758163.0                  758099.0
# mean         13.0          22.0                      15.0
# std           5.0          17.0                      26.0
# min           6.0           0.0                       0.0
# 25%           9.0           0.0                       2.0
# 50%          13.0          15.0                       7.0
# 75%          17.0          30.0                      16.0
# max          21.0          45.0                    1177.0
#
#        Number of cycle hire bikes  Total cycles  Unnamed: 14  Unnamed: 15  \
# count                    758099.0      758163.0          0.0          0.0
# mean                          2.0          17.0          NaN          NaN
# std                           3.0          29.0          NaN          NaN
# min                           0.0           0.0          NaN          NaN
# ...

# %% [markdown]
# ## Inner London

# %%
# Add new column
inner_df['Area'] = 'Inner'

# %%
# View dataframe
inner_df.head()
# Out:
#    Survey wave (year)   Site ID    Location    Survey date Weather  \
# 0              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 1              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 2              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 3              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 4              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
#
#           Time                       Period   Direction  Start hour  \
# 0  0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1  0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
# 2  0630 - 0645  Early Morning (06:00-07:00)  Northbound         6.0
# 3  0645 - 0700  Early Morning (06:00-07:00)  Northbound         6.0
# 4  0700 - 0715        AM peak (07:00-10:00)  Northbound         7.0
#
#    Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0           0.0                       1.0                         0.0
# ...

# %%
# View data types
inner_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615168 entries, 0 to 615167
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Survey wave (year)          523776 non-null  float64
#  1   Site ID                     523776 non-null  object
#  2   Location                    523776 non-null  object
#  3   Survey date                 521024 non-null  object
#  4   Weather                     519102 non-null  object
#  5   Time                        523770 non-null  object
#  6   Period                      523770 non-null  object
#  7   Direction                   523776 non-null  object
#  8   Start hour                  523770 non-null  float64
#  9   Start minute                523770 non-null  float64
#  10  Number of private cycles    523776 non-null  float64
#  11  Number of cycle hire bikes  523776 non-null  float64
# ...

# %%
# Identify missing values
inner_df.isna().sum()
# Out:
# Survey wave (year)            91392
# Site ID                       91392
# Location                      91392
# Survey date                   94144
# Weather                       96066
# Time                          91398
# Period                        91398
# Direction                     91392
# Start hour                    91398
# Start minute                  91398
# Number of private cycles      91392
# Number of cycle hire bikes    91392
# Total cycles                  91392
# Area                              0
# dtype: int64

# %%
# Explore
inner_df.describe().round()
# Out:
#        Survey wave (year)  Start hour  Start minute  Number of private cycles  \
# count            523776.0    523770.0      523770.0                  523776.0
# mean               2018.0        13.0          22.0                       6.0
# std                   2.0         5.0          17.0                      11.0
# min                2015.0         6.0           0.0                       0.0
# 25%                2016.0         9.0           0.0                       1.0
# 50%                2018.0        13.0          15.0                       3.0
# 75%                2020.0        17.0          30.0                       7.0
# max                2021.0        21.0          45.0                     278.0
#
#        Number of cycle hire bikes  Total cycles
# count                    523776.0      523776.0
# mean                          0.0           6.0
# std                           1.0          11.0
# min                           0.0           0.0
# ...

# %% [markdown]
# # Merge Dataframes

# %%
# Concatente data and reset index
london_df = pd.concat([central_df, inner_df,], ignore_index = True)

# %%
# View dataframe
london_df.head(2)
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16     Area  Survey wave (year)
# ...

# %%
# View dataframe
london_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1663534 entries, 0 to 1663533
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Survey wave (calendar quarter)  758163 non-null   object
#  1   Equivalent financial quarter    758163 non-null   object
#  2   Site ID                         1281939 non-null  object
#  3   Location                        1281939 non-null  object
#  4   Survey date                     1269031 non-null  object
#  5   Weather                         1265431 non-null  object
#  6   Time                            1281933 non-null  object
#  7   Period                          1281933 non-null  object
#  8   Direction                       1281939 non-null  object
#  9   Start hour                      1281933 non-null  float64
#  10  Start minute                    1281933 non-null  float64
# ...

# %% [markdown]
# # Clean new dataframe

# %%
# View missing values
london_df.isna().sum()
# Out:
# Survey wave (calendar quarter)     905371
# Equivalent financial quarter       905371
# Site ID                            381595
# Location                           381595
# Survey date                        394503
# Weather                            398103
# Time                               381601
# Period                             381601
# Direction                          381595
# Start hour                         381601
# Start minute                       381601
# Number of private cycles           381659
# Number of cycle hire bikes         381659
# Total cycles                       381595
# Unnamed: 14                       1663534
# Unnamed: 15                       1663534
# Unnamed: 16                       1663534
# Area                                    0
# Survey wave (year)                1139758
# dtype: int64

# %%
# Delete irrelevant columns
london_clean = london_df.drop(['Unnamed: 14','Unnamed: 15', 'Unnamed: 16','Survey wave (year)'], axis = 1)

# %%
#london_clean['Area'] = london_clean['Site ID'].str[:3]

# %%
# Create month column
london_clean['Month'] = london_clean['Survey date'].str.split('/').str[1]

# %%
# Create year column
london_clean['Year'] = london_clean['Survey date'].str.split('/').str[2]

# %%
london_clean['Year'] = '20' + london_clean['Year']

# %%
print(f" Number of months: {len(london_clean['Month'].value_counts())}")
# Out:
#  Number of months: 12

# %%
print(f" Number of years: {len(london_clean['Year'].value_counts())}")

london_clean['Year'].value_counts()
# Out:
#  Number of years: 8
# 2019    182848
# 2018    181332
# 2017    177708
# 2016    177664
# 2015    176948
# 2021    169043
# 2014    102540
# 2020    100692
# Name: Year, dtype: int64

# %%
# # Create own method with quarter mapping
# def categorise(row):
#     if row['Month'] <= 3:
#         return 'Q1'
#     elif row['Month'] >= 4 and row['Month'] <= 6:
#         return 'Q2'
#     elif row['Month'] >= 7 and row['Month'] <= 9:
#         return 'Q3'
#     return 'Q4'

# %%
# Pass method to apply() as lambda expression
# london_clean['Quarter'] = london_clean.apply(lambda row: categorise(row), axis = 1)

# %%
# subset_c['Quarter'].value_counts()

# %%
# # Combine Year and Quarter
# subset_c['Year-Q'] = subset_c['Year'].astype(str) + " " + subset_c['Quarter']

# %%
london_clean.shape
# Out:
# (1663534, 17)

# %%
london_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1663534 entries, 0 to 1663533
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Survey wave (calendar quarter)  758163 non-null   object
#  1   Equivalent financial quarter    758163 non-null   object
#  2   Site ID                         1281939 non-null  object
#  3   Location                        1281939 non-null  object
#  4   Survey date                     1269031 non-null  object
#  5   Weather                         1265431 non-null  object
#  6   Time                            1281933 non-null  object
#  7   Period                          1281933 non-null  object
#  8   Direction                       1281939 non-null  object
#  9   Start hour                      1281933 non-null  float64
#  10  Start minute                    1281933 non-null  float64
# ...

# %%
london_clean.head()
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# ...

# %%
# Examine what Survey date looks like when Month is missing but Survey date is not
sub_df = london_clean[london_clean['Month'].isnull() & ~ london_clean['Survey date'].isnull()]
print(sub_df['Survey date'])
# Out:
# 654784
# 654785
# 654786
# 654787
# 654788
#          ..
# 664251
# 664252
# 664253
# 664254
# 664255
# Name: Survey date, Length: 256, dtype: object

# %% [markdown]
# # Aggregate by Year - Inner & Central

# %%
# Aggregate table
london_ci_year = london_clean.groupby(['Year']).sum().reset_index().copy()

# %%
def percentage(col1,col2):
    return (col1 / col2) * 100

# %%
# Calculate percentage of private & Public cycle hires out of total cycles
london_ci_year['Private Cycles %'] = percentage(london_ci_year['Number of private cycles'],london_ci_year['Total cycles']).round(0)  
london_ci_year['Public Cycles hires %'] =  percentage(london_ci_year['Number of cycle hire bikes'],london_ci_year['Total cycles']).round(0)

# %%
# Print table
london_ci_year
# Out:
#    Year  Start hour  Start minute  Number of private cycles  \
# 0  2014   1384026.0     2307150.0                 1436361.0
# 1  2015   2389062.0     3981330.0                 1874494.0
# 2  2016   2398464.0     3997440.0                 1949401.0
# 3  2017   2399184.0     3998430.0                 1933072.0
# 4  2018   2447856.0     4079970.0                 2098528.0
# 5  2019   2468584.0     4114260.0                 2109351.0
# 6  2020   1359152.0     2265630.0                 1121425.0
# 7  2021   2281393.0     3803250.0                 1663633.0
#
#    Number of cycle hire bikes  Total cycles  Private Cycles %  \
# 0                    166636.0     1602997.0              90.0
# 1                    183630.0     2058124.0              91.0
# 2                    197309.0     2146710.0              91.0
# 3                    204267.0     2137339.0              90.0
# 4                    229746.0     2328274.0              90.0
# ...

# %%
sns.set(rc = {'figure.figsize':(25,10)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.lineplot(data = london_ci_year, x = 'Year', y = 'Total cycles', color = 'red', ci = None)
y.set_title('Total Cycles per Year in Central & Inner London', fontsize = 30)
y.set_xlabel('Survey Year', fontsize = 20)
y.set_ylabel('Total Cycles (M)', fontsize = 20)


plt.savefig('total cycles per year in central inner london.png', 
           transparent=True)

# %%
# Difference when using full dataset?
sns.set(rc = {'figure.figsize':(25,10)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.lineplot(data = london_clean, x = 'Year', y = 'Total cycles', color = 'red', ci = None)
y.set_title('Total Cycles per Year in Central & Inner London', fontsize = 30)
y.set_xlabel('Survey Year', fontsize = 20)
y.set_ylabel('Total Cycles (M)', fontsize = 20)
# Out:
# Text(0, 0.5, 'Total Cycles (M)')

# %%
sns.set(rc = {'figure.figsize':(25,10)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.lineplot(data = london_ci_year, x = 'Year', y = 'Number of private cycles', color = 'Orange', ci = None)
y.set_title('Private Cycles per Year in Central & Inner London', fontsize = 30)
y.set_xlabel('Survey Year', fontsize = 20)
y.set_ylabel('# of Private Cycles (M)', fontsize = 20)
# Out:
# Text(0, 0.5, '# of Private Cycles (M)')

# %%
sns.set(rc = {'figure.figsize':(25,10)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.lineplot(data = london_ci_year, x = 'Year', y = 'Number of cycle hire bikes', color = 'Green', ci = None)
y.set_title('Cycles hires per Year in Central & Inner London', fontsize = 30)
y.set_xlabel('Survey Year', fontsize = 20)
y.set_ylabel('# of Cycles hires', fontsize = 20)

plt.savefig('cycles hires per year in central inner london.png', 
           transparent=True)

# %% [markdown]
# Overall, total cycles increased each year from 2014 to 2019, then there was a sharp decrease in 2020 which may be due to the pandemic lockdown restrictions.

# %% [markdown]
# Private cycles acccounted for over 90% of the total cycles, whereas cycle hires accounted for 10% of total cycles only. This means majority of those who chooses to cycle uses their own bicycles. To increase the uptake of cycling, the government should target citizens using other modes of transport and convert them to cycling to increase cycle hires.

# %% [markdown]
# # Aggregate by Year - Inner London

# %%
# Create inner london subset
inner_clean = london_clean[london_clean['Area'] == 'Inner']

# %%
# Compare with original df
print(f" Shape of clean inner df: {inner_clean.shape}")

print(f" Shape of original inner df: {inner_df.shape}")
# Out:
#  Shape of clean inner df: (615168, 17)
#  Shape of original inner df: (615168, 14)

# %%
inner_clean.head()
# Out:
#         Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 1048366                            NaN                          NaN  INNCY001
# 1048367                            NaN                          NaN  INNCY001
# 1048368                            NaN                          NaN  INNCY001
# 1048369                            NaN                          NaN  INNCY001
# 1048370                            NaN                          NaN  INNCY001
#
#            Location    Survey date Weather         Time  \
# 1048366  Grove Road  mer, 20/05/15     Dry  0600 - 0615
# 1048367  Grove Road  mer, 20/05/15     Dry  0615 - 0630
# 1048368  Grove Road  mer, 20/05/15     Dry  0630 - 0645
# 1048369  Grove Road  mer, 20/05/15     Dry  0645 - 0700
# 1048370  Grove Road  mer, 20/05/15     Dry  0700 - 0715
#
#                               Period   Direction  Start hour  Start minute  \
# 1048366  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# ...

# %%
inner_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 615168 entries, 1048366 to 1663533
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Survey wave (calendar quarter)  0 non-null       object
#  1   Equivalent financial quarter    0 non-null       object
#  2   Site ID                         523776 non-null  object
#  3   Location                        523776 non-null  object
#  4   Survey date                     521024 non-null  object
#  5   Weather                         519102 non-null  object
#  6   Time                            523770 non-null  object
#  7   Period                          523770 non-null  object
#  8   Direction                       523776 non-null  object
#  9   Start hour                      523770 non-null  float64
#  10  Start minute                    523770 non-null  float64
# ...

# %%
london_clean['Year'].value_counts()
# Out:
# 2019    182848
# 2018    181332
# 2017    177708
# 2016    177664
# 2015    176948
# 2021    169043
# 2014    102540
# 2020    100692
# Name: Year, dtype: int64

# %%
inner_subset = london_clean[london_clean['Area'] == 'Inner']

inner_subset['Year'].value_counts()
# Out:
# 2021    91392
# 2015    76032
# 2016    76032
# 2018    76032
# 2019    75968
# 2017    75264
# 2020    50304
# Name: Year, dtype: int64

# %%
inner_df['Survey wave (year)'].value_counts()
# Out:
# 2021.0    91392
# 2015.0    76416
# 2016.0    76416
# 2017.0    76416
# 2018.0    76416
# 2019.0    76416
# 2020.0    50304
# Name: Survey wave (year), dtype: int64

# %% [markdown]
# Inner london does not have data in year 2014

# %%
# Create aggregate table
inner_year = inner_clean.groupby(['Year']).sum().reset_index().copy()

# %%
# Calculate percentage of private & Public cycle hires out of total cycles
inner_year['Private Cycles %'] = percentage(inner_year['Number of private cycles'],inner_year['Total cycles']).round(0)  
inner_year['Public Cycles hires %'] =  percentage(inner_year['Number of cycle hire bikes'],inner_year['Total cycles']).round(0)

# %%
# Print table
inner_year
# Out:
#    Year  Start hour  Start minute  Number of private cycles  \
# 0  2015   1026432.0     1710720.0                  432529.0
# 1  2016   1026432.0     1710720.0                  422989.0
# 2  2017   1016064.0     1693440.0                  423909.0
# 3  2018   1026432.0     1710720.0                  437631.0
# 4  2019   1025704.0     1709460.0                  422012.0
# 5  2020    679104.0     1131840.0                  408488.0
# 6  2021   1233666.0     2056140.0                  544663.0
#
#    Number of cycle hire bikes  Total cycles  Private Cycles %  \
# 0                     15890.0      448419.0              96.0
# 1                     17599.0      440588.0              96.0
# 2                     18086.0      441995.0              96.0
# 3                     20725.0      458356.0              95.0
# 4                     23855.0      445629.0              95.0
# 5                     20930.0      428940.0              95.0
# ...

# %%
sns.set(rc = {'figure.figsize':(25,10)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.lineplot(data = inner_year, x = 'Year', y = 'Total cycles', color = 'Red', ci = None)
y.set_title('Total Cycles per Year in Inner London', fontsize = 30)
y.set_xlabel('Survey Year', fontsize = 20)
y.set_ylabel('Total Cycles', fontsize = 20)

plt.savefig('total cycles per year in inner london.png', 
           transparent=True)

# %%
inner_year.columns
# Out:
# Index(['Year', 'Start hour', 'Start minute', 'Number of private cycles',
#        'Number of cycle hire bikes', 'Total cycles', 'Private Cycles %',
#        'Public Cycles hires %'],
#       dtype='object')

# %%
sns.set(rc = {'figure.figsize':(7,3)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.lineplot(data = inner_year, x = 'Year', y = 'Number of private cycles', color = 'Orange', ci = None)
# y.set_title('Private Cycles', fontsize = 30)
# y.set_xlabel('Survey Year', fontsize = 20)
# y.set_ylabel('# of Private Cycles', fontsize = 20)
y.set(ylabel = None, xlabel = None)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.savefig('Private Cycles per Year in Inner London.png', transparent=True, bbox_inches = 'tight')

# %%
sns.set(rc = {'figure.figsize':(7,3)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.lineplot(data = inner_year, x = 'Year', y = 'Number of cycle hire bikes', color = 'Green', ci = None)
#y.set_title('Cycles hires', fontsize = 30)
#y.set_xlabel('Survey Year', fontsize = 20)
#y.set_ylabel('# of Cycles hires', fontsize = 20)
y.set(ylabel = None, xlabel = None)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.savefig('Cycles hires per Year in Inner London.png', transparent=True, bbox_inches = 'tight')

# %% [markdown]
# # Aggregate by Year - Central London

# %%
# Create central london subset
central_clean = london_clean[london_clean['Area'] == 'Central']

# %%
# Compare with original df
print(f" Shape of clean central df: {central_clean.shape}")

print(f" Shape of original central df: {central_df.shape}")
# Out:
#  Shape of clean central df: (1048366, 17)
#  Shape of original central df: (1048366, 18)

# %%
central_clean.head()
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# ...

# %%
central_clean['Location'].value_counts()
# Out:
# Regent Street                    7424
# Charing Cross Road               7424
# Borough High Street              7296
# Southwark Street                 7168
# Lambeth Road                     5504
#                                  ...
# Pakenham Street                  1792
# Tooley Street (east)             1664
# Southwark Bridge Road (south)    1664
# Princess Street                  1664
# Sidmouth Square                  1536
# Name: Location, Length: 205, dtype: int64

# %%
inner_clean['Location'].value_counts()
# Out:
# Old Brompton Road       2048
# Peckham Rye             1920
# Harrow Road             1920
# Fulham Road             1920
# Trinity Road            1920
#                         ...
# Smallwood Road           640
# Auckland Hill            640
# St. James's Crescent     640
# Montague Avenue          640
# Ellerton Road            640
# Name: Location, Length: 584, dtype: int64

# %%
central_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1048366 entries, 0 to 1048365
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Survey wave (calendar quarter)  758163 non-null   object
#  1   Equivalent financial quarter    758163 non-null   object
#  2   Site ID                         758163 non-null   object
#  3   Location                        758163 non-null   object
#  4   Survey date                     748007 non-null   object
#  5   Weather                         746329 non-null   object
#  6   Time                            758163 non-null   object
#  7   Period                          758163 non-null   object
#  8   Direction                       758163 non-null   object
#  9   Start hour                      758163 non-null   float64
#  10  Start minute                    758163 non-null   float64
# ...

# %%
# Create aggregate table
central_year = central_clean.groupby(['Year']).sum().reset_index().copy()

# %%
# Calculate percentage of private & Public cycle hires out of total cycles
central_year['Private Cycles %'] = percentage(central_year['Number of private cycles'],central_year['Total cycles']).round(0)  
central_year['Public Cycles hires %'] =  percentage(central_year['Number of cycle hire bikes'],central_year['Total cycles']).round(0)

# %%
# Print table
central_year
# Out:
#    Year  Start hour  Start minute  Number of private cycles  \
# 0  2014   1384026.0     2307150.0                 1436361.0
# 1  2015   1362630.0     2270610.0                 1441965.0
# 2  2016   1372032.0     2286720.0                 1526412.0
# 3  2017   1383120.0     2304990.0                 1509163.0
# 4  2018   1421424.0     2369250.0                 1660897.0
# 5  2019   1442880.0     2404800.0                 1687339.0
# 6  2020    680048.0     1133790.0                  712937.0
# 7  2021   1047727.0     1747110.0                 1118970.0
#
#    Number of cycle hire bikes  Total cycles  Private Cycles %  \
# 0                    166636.0     1602997.0              90.0
# 1                    167740.0     1609705.0              90.0
# 2                    179710.0     1706122.0              89.0
# 3                    186181.0     1695344.0              89.0
# 4                    209021.0     1869918.0              89.0
# ...

# %%
# Export table to CSV
central_year.to_csv(dir + '/Output/central_year.csv')

# %%
sns.set(rc = {'figure.figsize':(25,10)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.lineplot(data = central_year, x = 'Year', y = 'Total cycles', color = 'Red', ci = None)
y.set_title('Total Cycles per Year in Central London', fontsize = 30)
y.set_xlabel('Survey Year', fontsize = 20)
y.set_ylabel('Total Cycles', fontsize = 20)
# Out:
# Text(0, 0.5, 'Total Cycles')

# %%
central_year.columns
# Out:
# Index(['Year', 'Start hour', 'Start minute', 'Number of private cycles',
#        'Number of cycle hire bikes', 'Total cycles', 'Private Cycles %',
#        'Public Cycles hires %'],
#       dtype='object')

# %%
sns.set(rc = {'figure.figsize':(7,3)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.lineplot(data = central_year, x = 'Year', y = 'Number of private cycles', color = 'Orange', ci = None)
#y.set_title('Private Cycles', fontsize = 30)
#y.set_xlabel('Survey Year', fontsize = 20)
#y.set_ylabel('# of Private Cycles', fontsize = 20)
y.set(ylabel = None, xlabel = None)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.savefig('Private Cycles per Year in Central London.png', transparent=True, bbox_inches = 'tight')

# %%
sns.set(rc = {'figure.figsize':(7,3)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.lineplot(data = central_year, x = 'Year', y = 'Number of cycle hire bikes', color = 'Green', ci = None)
#y.set_title('Cycles hires', fontsize = 30)
#y.set_xlabel('Survey Year', fontsize = 20)
#y.set_ylabel('# of Cycles hires', fontsize = 20)
y.set(ylabel = None, xlabel = None)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.savefig('Cycles hires per Year in Central London.png', transparent=True, bbox_inches = 'tight')

# %% [markdown]
# # Compare Inner vs Central London

# %%
# Group by area and year
year = london_clean.groupby(['Area','Year']).sum().reset_index().copy()

year.dtypes
# Out:
# Area                           object
# Year                           object
# Start hour                    float64
# Start minute                  float64
# Number of private cycles      float64
# Number of cycle hire bikes    float64
# Total cycles                  float64
# dtype: object

# %%
sns.set(rc = {'figure.figsize':(25,10)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.barplot(data = year, x = 'Year', y = 'Total cycles', hue = 'Area')
y.set_title('Total Cycles per Year', fontsize = 30)
y.set_xlabel('Survey Year', fontsize = 20)
y.set_ylabel('Total Cycles', fontsize = 20)

plt.savefig('Total Cycles per Year.png')

# %%
sns.set(rc = {'figure.figsize':(10,5)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.barplot(data = year, x = 'Year', y = 'Number of cycle hire bikes', hue = 'Area')
y.set_title('Cycles hires per Year', fontsize = 30)
y.set_xlabel('Survey Year', fontsize = 20)
y.set_ylabel('# of Cycles hires', fontsize = 20)


plt.savefig('Cycles hires per Year.png')

# %%
sns.set(rc = {'figure.figsize':(10,5)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.barplot(data = year, x = 'Year', y = 'Number of private cycles', hue = 'Area')
y.set_title('Private Cycles per Year', fontsize = 30)
y.set_xlabel('Survey Year', fontsize = 20)
y.set_ylabel('# of Private Cycles', fontsize = 20)

plt.savefig('Private Cycles per Year.png')

# %% [markdown]
# # Aggregate by Direction

# %%
london_clean.head(2)
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
#
#       Area Month  Year
# 0  Central    01  2014
# 1  Central    01  2014

# %%
london_clean['Direction'].value_counts()
# Out:
# Southbound    349441
# Northbound    349280
# Westbound     291642
# Eastbound     291576
# Name: Direction, dtype: int64

# %%
direction = london_clean.groupby(['Area','Direction']).sum().reset_index().copy()

direction
# Out:
#       Area   Direction  Start hour  Start minute  Number of private cycles  \
# 0  Central   Eastbound   2351048.0     3918780.0                 2541398.0
# 1  Central  Northbound   2764800.0     4608000.0                 3151161.0
# 2  Central  Southbound   2766850.0     4611600.0                 2953429.0
# 3  Central   Westbound   2351941.0     3920250.0                 2592355.0
# 4    Inner   Eastbound   1584880.0     2641680.0                  656102.0
# 5    Inner  Northbound   1950482.0     3250620.0                  889372.0
# 6    Inner  Southbound   1950608.0     3250800.0                  894455.0
# 7    Inner   Westbound   1584880.0     2641680.0                  665975.0
#
#    Number of cycle hire bikes  Total cycles
# 0                    372721.0     2914119.0
# 1                    320705.0     3471866.0
# 2                    316395.0     3269824.0
# 3                    377555.0     2969910.0
# 4                     32906.0      688735.0
# ...

# %%
d = sns.barplot(data = direction, x = 'Area', y = 'Total cycles', hue = 'Direction')
d.set_title('Total Cycles categories by direction', fontsize = 20)
d.set_xlabel('Area', fontsize = 20)
d.set_ylabel('Total Cycles', fontsize = 20)

plt.savefig('Total Cycles categories by direction.png')

# %%
d = sns.barplot(data = direction, x = 'Area', y = 'Number of private cycles', hue = 'Direction')
d.set_title('Private Cycles categories by direction', fontsize = 20)
d.set_xlabel('Area', fontsize = 20)
d.set_ylabel('# of Private Cycles', fontsize = 20)

plt.savefig('Private Cycles categories by direction.png')

# %%
d = sns.barplot(data = direction, x = 'Area', y = 'Number of cycle hire bikes', hue = 'Direction')
d.set_title('Cycles hires categories by direction', fontsize = 20)
d.set_xlabel('Area', fontsize = 20)
d.set_ylabel('# of Cycle hires', fontsize = 20)

plt.savefig('Cycles hires categories by direction.png')

# %% [markdown]
# In central london, more people hire cycles when travelling towards eastbound and westbound, while more people use private cycles when travelling towards north and south bound.
# In inner london, most people hire cycles or use private cycles when travlling towards in northbound and southbound. This means people are less likely to cycle when travelling towards east and west bound in inner london.
#
# Is this due to the lack of infrastructure in in central london towards north and southbound?

# %% [markdown]
# # Aggregate by Period

# %%
london_clean.head()
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# ...

# %%
period = london_clean.groupby(['Area','Period']).sum().reset_index().copy()

period
# Out:
#       Area                       Period  Start hour  Start minute  \
# 0  Central        AM peak (07:00-10:00)   1137408.0     3198960.0
# 1  Central  Early Morning (06:00-07:00)    284352.0     1066320.0
# 2  Central        Evening (19:00-22:00)   2842320.0     3197610.0
# 3  Central     Inter-peak (10:00-16:00)   3554313.0     6397770.0
# 4  Central        PM peak (16:00-19:00)   2416246.0     3197970.0
# 5    Inner        AM peak (07:00-10:00)    785664.0     2209680.0
# 6    Inner  Early Morning (06:00-07:00)    196416.0      736560.0
# 7    Inner        Evening (19:00-22:00)   1964034.0     2209500.0
# 8    Inner     Inter-peak (10:00-16:00)   2455200.0     4419360.0
# 9    Inner        PM peak (16:00-19:00)   1669536.0     2209680.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles
# 0                 3805126.0                    436309.0     4241435.0
# 1                  289492.0                     29111.0      318603.0
# ...

# %%
p = sns.barplot(data = period, x = 'Area', y = 'Total cycles', hue = 'Period')
p.set_title('Total Cycles categories by period', fontsize = 20)
p.set_xlabel('Area', fontsize = 20)
p.set_ylabel('Total Cycles', fontsize = 20)
# Out:
# Text(0, 0.5, 'Total Cycles')

# %%
d = sns.barplot(data = period, x = 'Area', y = 'Number of private cycles', hue = 'Period')
d.set_title('Private Cycles categories by period', fontsize = 20)
d.set_xlabel('Area', fontsize = 20)
d.set_ylabel('# of Private Cycles', fontsize = 20)

plt.savefig('Private Cycles categories by period.png')

# %%
d = sns.barplot(data = period, x = 'Area', y = 'Number of cycle hire bikes', hue = 'Period')
d.set_title('Cycles hires categories by period', fontsize = 20)
d.set_xlabel('Area', fontsize = 20)
d.set_ylabel('# of Cycle hires', fontsize = 20)

plt.savefig('Cycles hires categories by period.png')

# %% [markdown]
# # Weather

# %%
pd.set_option('display.max_rows', 404)
london_clean['Weather'].value_counts()
# Out:
# Dry                              1054630
# Wet                               134318
# Fine                               20282
# Sunny                              10690
# Cloudy                             10134
# Rain                                8386
# N/a                                 2048
# Drizzle                             1510
# Dry/sunny                           1270
# Fair                                1020
# Light Rain                           968
# Damp                                 771
# D                                    736
# Dry/wet                              644
# Unknown                              640
# Wet/dry                              516
# Clear and Warm                       432
# Windy                                414
# Wet                                  408
# Cold/rain                            384
# Wet Road                             366
# Cold                                 346
# Overcast                             300
# ...

# %%
# Create subset

conditions = ['Dry', 'Wet', 'Fine', 'Sunny', 'Cloudy', 'Rain']

weather_inner = london_clean[(london_clean['Weather'].isin(conditions)) & (london_clean['Area'] == 'Inner')]

weather_inner
# Out:
#         Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 1048366                            NaN                          NaN  INNCY001
# 1048367                            NaN                          NaN  INNCY001
# 1048368                            NaN                          NaN  INNCY001
# 1048369                            NaN                          NaN  INNCY001
# 1048370                            NaN                          NaN  INNCY001
# ...                                ...                          ...       ...
# 1572137                            NaN                          NaN  INNCY597
# 1572138                            NaN                          NaN  INNCY597
# 1572139                            NaN                          NaN  INNCY597
# 1572140                            NaN                          NaN  INNCY597
# 1572141                            NaN                          NaN  INNCY597
#
# ...

# %%
inner_agg = weather_inner.groupby(['Weather']).sum().reset_index()

inner_agg
# Out:
#   Weather  Start hour  Start minute  Number of private cycles  \
# 0  Cloudy     79242.0      128430.0                   38871.0
# 1     Dry   5863552.0     9762780.0                 2643635.0
# 2    Fine     18660.0       32340.0                    3813.0
# 3    Rain     40026.0       67080.0                   12228.0
# 4   Sunny    103417.0      179340.0                   49402.0
# 5     Wet    757372.0     1265295.0                  276595.0
#
#    Number of cycle hire bikes  Total cycles
# 0                      3307.0       42178.0
# 1                    119547.0     2762567.0
# 2                        10.0        3823.0
# 3                       796.0       13024.0
# 4                      3596.0       52998.0
# 5                      9856.0      286350.0

# %%
sns.set(rc = {'figure.figsize':(25,15)}, font_scale = 2)
sns.barplot(data = inner_agg, x = 'Weather', y = 'Number of private cycles')
# Out:
# <AxesSubplot:xlabel='Weather', ylabel='Number of private cycles'>

# %%
sns.set(rc = {'figure.figsize':(25,15)}, font_scale = 2)
sns.barplot(data = inner_agg, x = 'Weather', y = 'Number of cycle hire bikes')
# Out:
# <AxesSubplot:xlabel='Weather', ylabel='Number of cycle hire bikes'>

# %%
inner_agg_yr = weather_inner.groupby(['Weather','Year']).sum().reset_index()

inner_agg_yr
# Out:
#    Weather  Year  Start hour  Start minute  Number of private cycles  \
# 0   Cloudy  2015      7614.0       11970.0                    2175.0
# 1   Cloudy  2016     19208.0       30090.0                   10632.0
# 2   Cloudy  2017     13634.0       22440.0                    5656.0
# 3   Cloudy  2018     13560.0       22770.0                    4350.0
# 4   Cloudy  2019     13966.0       22260.0                    9632.0
# 5   Cloudy  2021     11260.0       18900.0                    6426.0
# 6      Dry  2015    912852.0     1510950.0                  389270.0
# 7      Dry  2016    806232.0     1341420.0                  334444.0
# 8      Dry  2017    852786.0     1430460.0                  365801.0
# 9      Dry  2018    917820.0     1519860.0                  399442.0
# 10     Dry  2019    852703.0     1427640.0                  367824.0
# 11     Dry  2020    486362.0      800820.0                  302677.0
# 12     Dry  2021   1027575.0     1719000.0                  481780.0
# ...

# %%
sns.barplot(data = inner_agg_yr, x = 'Year', y = 'Number of private cycles', hue = 'Weather')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Number of private cycles'>

# %%
sns.barplot(data = inner_agg_yr, x = 'Year', y = 'Number of cycle hire bikes', hue = 'Weather')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Number of cycle hire bikes'>

# %% [markdown]
# # Infrastructure

# %%
london_clean
# Out:
#         Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4              2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# ...                                ...                          ...       ...
# 1663529                            NaN                          NaN       NaN
# 1663530                            NaN                          NaN       NaN
# 1663531                            NaN                          NaN       NaN
# 1663532                            NaN                          NaN       NaN
# 1663533                            NaN                          NaN       NaN
#
# ...

# %%
london_clean['Location'].value_counts()
# Out:
# Charing Cross Road      7424
# Regent Street           7424
# Borough High Street     7296
# Southwark Street        7168
# Lambeth Road            5504
#                         ...
# Ellerton Road            640
# Auckland Hill            640
# Montague Avenue          640
# St. James's Crescent     640
# Sellincourt Road         640
# Name: Location, Length: 785, dtype: int64

# %%
london_clean['Site ID'].value_counts()
# Out:
# CENCY008    3714
# CENCY001    3712
# CENCY136    3712
# CENCY125    3712
# CENCY126    3712
#             ...
# INNCY463     640
# INNCY456     640
# INNCY455     640
# INNCY350     640
# INNCY479     640
# Name: Site ID, Length: 807, dtype: int64

# %% [markdown]
# # Inner London

# %%
direc = ['Eastbound', 'Westbound']

inner_direction = london_clean[(london_clean['Direction'].isin(direc)) & (london_clean['Area'] == 'Inner')]

inner_direction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234816 entries, 1048494 to 1572141
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Survey wave (calendar quarter)  0 non-null       object
#  1   Equivalent financial quarter    0 non-null       object
#  2   Site ID                         234816 non-null  object
#  3   Location                        234816 non-null  object
#  4   Survey date                     233502 non-null  object
#  5   Weather                         232356 non-null  object
#  6   Time                            234816 non-null  object
#  7   Period                          234816 non-null  object
#  8   Direction                       234816 non-null  object
#  9   Start hour                      234816 non-null  float64
#  10  Start minute                    234816 non-null  float64
# ...

# %% [markdown]
# ## Inner East London

# %%
inner_east = london_clean[(london_clean['Direction'] == 'Eastbound') & (london_clean['Area'] == 'Inner')]

inner_east.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117408 entries, 1048494 to 1572077
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Survey wave (calendar quarter)  0 non-null       object
#  1   Equivalent financial quarter    0 non-null       object
#  2   Site ID                         117408 non-null  object
#  3   Location                        117408 non-null  object
#  4   Survey date                     116751 non-null  object
#  5   Weather                         116178 non-null  object
#  6   Time                            117408 non-null  object
#  7   Period                          117408 non-null  object
#  8   Direction                       117408 non-null  object
#  9   Start hour                      117408 non-null  float64
#  10  Start minute                    117408 non-null  float64
# ...

# %%
len(inner_east['Location'].value_counts())
# Out:
# 274

# %%
# Inner london location cycle towards Eastbound
inner_east_loc = inner_east.groupby(['Location'])[['Number of private cycles','Number of cycle hire bikes','Total cycles']].sum().reset_index().sort_values(by = 'Number of cycle hire bikes', ascending = True)

# %%
sns.boxplot(data = inner_east_loc, x = 'Total cycles')
# Out:
# <AxesSubplot:xlabel='Total cycles'>

# %%
inner_east_loc.describe().round()
# Out:
#        Number of private cycles  Number of cycle hire bikes  Total cycles
# count                     274.0                       274.0         274.0
# mean                     2395.0                       120.0        2514.0
# std                      2855.0                       279.0        3046.0
# min                        24.0                         0.0          24.0
# 25%                       510.0                         3.0         539.0
# 50%                      1182.0                        14.0        1237.0
# 75%                      3258.0                        93.0        3434.0
# max                     14470.0                      2354.0       16002.0

# %%
inner_east_loc.shape
# Out:
# (274, 4)

# %%
inner_east_loc.head(10)
# Out:
#               Location  Number of private cycles  Number of cycle hire bikes  \
# 151          Link Road                     355.0                         0.0
# 220   Sellincourt Road                     161.0                         0.0
# 146      Lenthall Road                     200.0                         0.0
# 170       Merton Abbey                     109.0                         0.0
# 212    Ravensbury Road                     922.0                         0.0
# 35   Cambridge Gardens                      80.0                         0.0
# 210      Ramsdale Road                      24.0                         0.0
# 209        Queens Road                     720.0                         0.0
# 80       Emmanuel Road                    2032.0                         0.0
# 153        London Road                    2958.0                         0.0
#
#      Total cycles
# 151         355.0
# 220         161.0
# 146         200.0
# 170         109.0
# 212         922.0
# ...

# %%
# Less than 10 cycle hire bikes
inner_east_loc_least = inner_east_loc[inner_east_loc['Number of cycle hire bikes'] == 0 ].sort_values(by = 'Total cycles', ascending = True)

inner_east_loc_least.shape
# Out:
# (29, 4)

# %%
inner_east_loc_least_10 = inner_east_loc_least.head(10)

inner_east_loc_least_10
# Out:
#                    Location  Number of private cycles  \
# 210           Ramsdale Road                      24.0
# 154          Longton Avenue                      68.0
# 9            Atheldene Road                      74.0
# 35        Cambridge Gardens                      80.0
# 251       Thorpewood Avenue                      89.0
# 170            Merton Abbey                     109.0
# 184            Norwood Park                     111.0
# 16           Babington Road                     120.0
# 11            Auckland Hill                     130.0
# 229  St. Julian's Farm Road                     134.0
#
#      Number of cycle hire bikes  Total cycles
# 210                         0.0          24.0
# 154                         0.0          68.0
# 9                           0.0          74.0
# 35                          0.0          80.0
# 251                         0.0          89.0
# 170                         0.0         109.0
# ...

# %%
sns.set(rc = {'figure.figsize':(20,10)}, font_scale = 10)
sns.set_theme(style="ticks")
ie = sns.barplot(data = inner_east_loc_least_10, x = "Location", y = "Total cycles")
ie.set_title('Top 10 Roads with Least Cycles in Inner East London', fontsize = 40)
ie.set_xlabel('Location', fontsize = 20)
ie.set_ylabel('Total Cycles', fontsize = 20)
plt.xticks(rotation=15, fontsize=25)
plt.yticks(fontsize=20)
for i in ie.containers:
    ie.bar_label(i,)

plt.savefig('Top 10 Roads with Least Cycle in Inner East.png')

# %% [markdown]
# ## Inner West London

# %%
inner_west = london_clean[(london_clean['Direction'] == 'Westbound') & (london_clean['Area'] == 'Inner')]

inner_west.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117408 entries, 1048558 to 1572141
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Survey wave (calendar quarter)  0 non-null       object
#  1   Equivalent financial quarter    0 non-null       object
#  2   Site ID                         117408 non-null  object
#  3   Location                        117408 non-null  object
#  4   Survey date                     116751 non-null  object
#  5   Weather                         116178 non-null  object
#  6   Time                            117408 non-null  object
#  7   Period                          117408 non-null  object
#  8   Direction                       117408 non-null  object
#  9   Start hour                      117408 non-null  float64
#  10  Start minute                    117408 non-null  float64
# ...

# %%
len(inner_west['Location'].value_counts())
# Out:
# 274

# %%
# Inner london location cycle towards Westbound
inner_west_loc = inner_west.groupby(['Location'])[['Number of private cycles','Number of cycle hire bikes','Total cycles']].sum().reset_index().sort_values(by = 'Number of cycle hire bikes', ascending = True)

# %%
sns.boxplot(data = inner_west_loc, x = 'Total cycles')
# Out:
# <AxesSubplot:xlabel='Total cycles'>

# %%
inner_west_loc.describe().round()
# Out:
#        Number of private cycles  Number of cycle hire bikes  Total cycles
# count                     274.0                       274.0         274.0
# mean                     2431.0                       118.0        2547.0
# std                      2929.0                       263.0        3101.0
# min                        31.0                         0.0          31.0
# 25%                       542.0                         2.0         543.0
# 50%                      1208.0                        13.0        1278.0
# 75%                      3168.0                        98.0        3253.0
# max                     16663.0                      2018.0       17701.0

# %%
inner_west_loc.head(5)
# Out:
#             Location  Number of private cycles  Number of cycle hire bikes  \
# 135  Kingscourt Road                     114.0                         0.0
# 170     Merton Abbey                     233.0                         0.0
# 88     Florence Road                     959.0                         0.0
# 84       Fawley Road                     109.0                         0.0
# 184     Norwood Park                      62.0                         0.0
#
#      Total cycles
# 135         114.0
# 170         233.0
# 88          959.0
# 84          109.0
# 184          62.0

# %%
inner_west_loc_least = inner_west_loc[inner_west_loc['Number of cycle hire bikes'] == 0 ].sort_values(by = 'Total cycles', ascending = True)

inner_west_10_least = inner_west_loc_least.head(10)

inner_west_10_least
# Out:
#                    Location  Number of private cycles  \
# 210           Ramsdale Road                      31.0
# 251       Thorpewood Avenue                      57.0
# 184            Norwood Park                      62.0
# 154          Longton Avenue                      85.0
# 9            Atheldene Road                      94.0
# 229  St. Julian's Farm Road                     102.0
# 158            Lyveden Road                     105.0
# 16           Babington Road                     108.0
# 84              Fawley Road                     109.0
# 35        Cambridge Gardens                     112.0
#
#      Number of cycle hire bikes  Total cycles
# 210                         0.0          31.0
# 251                         0.0          57.0
# 184                         0.0          62.0
# 154                         0.0          85.0
# 9                           0.0          94.0
# 229                         0.0         102.0
# ...

# %%
sns.set(rc = {'figure.figsize':(20,10)}, font_scale = 10)
sns.set_theme(style="ticks")
ie = sns.barplot(data = inner_west_10_least, x = 'Location', y = 'Total cycles')
ie.set_title('Top 10 Roads with Least Cycles in Inner West London', fontsize = 40)
ie.set_xlabel('Location', fontsize = 20)
ie.set_ylabel('Total Cycles', fontsize = 20)
plt.xticks(rotation=15, fontsize=20)
plt.yticks(fontsize=20)
for i in ie.containers:
    ie.bar_label(i,)


plt.savefig('Top 10 Roads with Least Cycle in inner west.png')

# %% [markdown]
# # Inner West & East

# %%
inner_east_west = london_clean[((london_clean['Direction'] == 'Eastbound') | (london_clean['Direction'] == 'Westbound')) & (london_clean['Area'] == 'Inner')]

inner_east_west
# Out:
#         Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 1048494                            NaN                          NaN  INNCY002
# 1048495                            NaN                          NaN  INNCY002
# 1048496                            NaN                          NaN  INNCY002
# 1048497                            NaN                          NaN  INNCY002
# 1048498                            NaN                          NaN  INNCY002
# ...                                ...                          ...       ...
# 1572137                            NaN                          NaN  INNCY597
# 1572138                            NaN                          NaN  INNCY597
# 1572139                            NaN                          NaN  INNCY597
# 1572140                            NaN                          NaN  INNCY597
# 1572141                            NaN                          NaN  INNCY597
#
# ...

# %%
inner_east_west['Area'].value_counts()
# Out:
# Inner    234816
# Name: Area, dtype: int64

# %%
inner_east_west['Direction'].value_counts()
# Out:
# Eastbound    117408
# Westbound    117408
# Name: Direction, dtype: int64

# %%
inner_loc = inner_east_west.groupby(['Location'])[['Number of private cycles','Number of cycle hire bikes','Total cycles']].sum().reset_index().sort_values('Total cycles', ascending = True)

inner_least_5 = inner_loc.head(5)

inner_least_5
# Out:
#               Location  Number of private cycles  Number of cycle hire bikes  \
# 210      Ramsdale Road                      55.0                         0.0
# 8        Aslett Street                     144.0                         2.0
# 251  Thorpewood Avenue                     146.0                         0.0
# 154     Longton Avenue                     153.0                         0.0
# 9       Atheldene Road                     168.0                         0.0
#
#      Total cycles
# 210          55.0
# 8           146.0
# 251         146.0
# 154         153.0
# 9           168.0

# %%
sns.set(rc = {'figure.figsize':(6,10)}, font_scale = 8)
sns.set_theme(style="ticks")
ie = sns.barplot(data = inner_least_5, y = 'Location', x = 'Total cycles')
ie.set_title('Inner', fontsize = 30)
#ie.set_xlabel('Location', fontsize = 20)
#ie.set_ylabel('Total Cycles', fontsize = 20)
ie.set(ylabel=None)
plt.xticks(fontsize=15)
plt.yticks(fontsize=20, rotation = 50)
for i in ie.containers:
    ie.bar_label(i,)


plt.savefig('Top 5 East West Roads with Least Cycle in Inner London.png', bbox_inches = 'tight', transparent = True)

# %%
inner_east_west['Year'].unique()
# Out:
# array(['2015', nan, '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype=object)

# %%
ramsdale = inner_east_west[inner_east_west['Location'] == 'Ramsdale Road']

ramsdale.shape
# Out:
# (128, 17)

# %%
sns.lineplot(data = ramsdale, x = 'Year', y = 'Total cycles')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total cycles'>

# %%
thorpewood = inner_east_west[inner_east_west['Location'] == 'Thorpewood Avenue']

thorpewood.shape
# Out:
# (640, 17)

# %%
sns.lineplot(data = thorpewood, x = 'Year', y = 'Total cycles', ci = None)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total cycles'>

# %%
aslett = inner_east_west[inner_east_west['Location'] == 'Aslett Street']

aslett.shape
# Out:
# (640, 17)

# %%
sns.lineplot(data = aslett, x = 'Year', y = 'Total cycles', ci = None)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total cycles'>

# %% [markdown]
# # Central Eastbound

# %%
central_east = london_clean[(london_clean['Direction'] == 'Eastbound') & (london_clean['Area'] == 'Central')]

central_east.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174168 entries, 512 to 757842
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Survey wave (calendar quarter)  174168 non-null  object
#  1   Equivalent financial quarter    174168 non-null  object
#  2   Site ID                         174168 non-null  object
#  3   Location                        174168 non-null  object
#  4   Survey date                     172036 non-null  object
#  5   Weather                         171869 non-null  object
#  6   Time                            174168 non-null  object
#  7   Period                          174168 non-null  object
#  8   Direction                       174168 non-null  object
#  9   Start hour                      174168 non-null  float64
#  10  Start minute                    174168 non-null  float64
# ...

# %%
# Central london location cycle towards Eastbound
central_east_loc = central_east.groupby(['Location'])[['Number of private cycles','Number of cycle hire bikes','Total cycles']].sum().reset_index().sort_values('Number of cycle hire bikes', ascending = True)

print(central_east_loc.shape)

central_east_loc_10 = central_east_loc.head(10).sort_values('Total cycles', ascending = True)

central_east_loc_10
# Out:
# (97, 4)
#                         Location  Number of private cycles  \
# 72                 Stanhope Gate                     231.0
# 3                 Belvedere Road                     426.0
# 31              Grosvenor Street                     468.0
# 54          New Cavendish Street                     464.0
# 4                    Bevis Marks                    1029.0
# 19  Crucifix Lane (Druid Street)                    1513.0
# 32               Hastings Street                    1744.0
# 21                  Eagle Street                    2263.0
# 30               Greville Street                    4205.0
# 43                   Lime Street                    5258.0
#
#     Number of cycle hire bikes  Total cycles
# 72                       157.0         388.0
# 3                        124.0         550.0
# 31                        93.0         561.0
# 54                       225.0         689.0
# 4                        125.0        1154.0
# ...

# %%
sns.set(rc = {'figure.figsize':(20,10)}, font_scale = 10)
sns.set_theme(style="ticks")
ie = sns.barplot(data = central_east_loc_10, x = 'Location', y = 'Total cycles')
ie.set_title('Top 10 Roads with Least Cycles in Central East London', fontsize = 40)
ie.set_xlabel('Location', fontsize = 20)
ie.set_ylabel('Total Cycles', fontsize = 20)
plt.xticks(rotation=15, fontsize=20)
plt.yticks(fontsize=20)
for i in ie.containers:
    ie.bar_label(i,)


plt.savefig('Top 10 Roads with Least Cycle in Central East.png')

# %% [markdown]
# # Central Westbound

# %%
central_west = london_clean[(london_clean['Direction'] == 'Westbound') & (london_clean['Area'] == 'Central')]

central_west.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174234 entries, 576 to 757906
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Survey wave (calendar quarter)  174234 non-null  object
#  1   Equivalent financial quarter    174234 non-null  object
#  2   Site ID                         174234 non-null  object
#  3   Location                        174234 non-null  object
#  4   Survey date                     172102 non-null  object
#  5   Weather                         171935 non-null  object
#  6   Time                            174234 non-null  object
#  7   Period                          174234 non-null  object
#  8   Direction                       174234 non-null  object
#  9   Start hour                      174234 non-null  float64
#  10  Start minute                    174234 non-null  float64
# ...

# %%
# Central london location cycle towards Eastbound
central_west_loc = central_west.groupby(['Location'])[['Number of private cycles','Number of cycle hire bikes','Total cycles']].sum().reset_index().sort_values('Number of cycle hire bikes', ascending = True)

print(central_west_loc.shape)

central_west_loc_10 = central_west_loc.head(10).sort_values('Total cycles', ascending = True)

central_west_loc_10
# Out:
# (97, 4)
#                               Location  Number of private cycles  \
# 3                       Belvedere Road                     447.0
# 37                         Houndsditch                     514.0
# 78                        Temple Place                    1469.0
# 10                        Brook Street                    1597.0
# 21                        Eagle Street                    2782.0
# 49  Millbank (south of Thorney Street)                    2828.0
# 30                     Greville Street                    2920.0
# 43                         Lime Street                    3630.0
# 32                     Hastings Street                    4537.0
# 27                 Great Ormond Street                    5321.0
#
#     Number of cycle hire bikes  Total cycles
# 3                        113.0         560.0
# 37                        70.0         584.0
# 78                       334.0        1803.0
# 10                       398.0        1995.0
# ...

# %%
sns.set(rc = {'figure.figsize':(20,10)}, font_scale = 10)
sns.set_theme(style="ticks")
ie = sns.barplot(data = central_west_loc_10, x = 'Location', y = 'Total cycles')
ie.set_title('Top 10 Roads with Least Cycles in Central West London', fontsize = 40)
ie.set_xlabel('Location', fontsize = 20)
ie.set_ylabel('Total Cycles', fontsize = 20)
plt.xticks(rotation=15, fontsize=20)
plt.yticks(fontsize=20)
for i in ie.containers:
    ie.bar_label(i,)


plt.savefig('Top 10 Roads with Least Cycle in Central West.png')

# %% [markdown]
# # Central West & East

# %%
central_east_west = london_clean[((london_clean['Direction'] == 'Eastbound') | (london_clean['Direction'] == 'Westbound')) & (london_clean['Area'] == 'Central')]

central_east_west
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 512           2014 Q1 (January-March)                   2013-14 Q4  CENCY005
# 513           2014 Q1 (January-March)                   2013-14 Q4  CENCY005
# 514           2014 Q1 (January-March)                   2013-14 Q4  CENCY005
# 515           2014 Q1 (January-March)                   2013-14 Q4  CENCY005
# 516           2014 Q1 (January-March)                   2013-14 Q4  CENCY005
# ...                               ...                          ...       ...
# 757902    2021 Q4 (October-December)                    2021-22 Q3  CENCY209
# 757903    2021 Q4 (October-December)                    2021-22 Q3  CENCY209
# 757904    2021 Q4 (October-December)                    2021-22 Q3  CENCY209
# 757905    2021 Q4 (October-December)                    2021-22 Q3  CENCY209
# 757906    2021 Q4 (October-December)                    2021-22 Q3  CENCY209
#
# ...

# %%
central_east_west['Area'].value_counts()
# Out:
# Central    348402
# Name: Area, dtype: int64

# %%
central_east_west['Direction'].value_counts()
# Out:
# Westbound    174234
# Eastbound    174168
# Name: Direction, dtype: int64

# %%
central_loc = central_east_west.groupby(['Location'])[['Number of private cycles','Number of cycle hire bikes','Total cycles']].sum().reset_index().sort_values('Total cycles', ascending = True)

central_least_5 = central_loc.head(5)

central_least_5
# Out:
#                               Location  Number of private cycles  \
# 3                       Belvedere Road                     873.0
# 72                       Stanhope Gate                    2184.0
# 21                        Eagle Street                    5045.0
# 49  Millbank (south of Thorney Street)                    5277.0
# 32                     Hastings Street                    6281.0
#
#     Number of cycle hire bikes  Total cycles
# 3                        237.0        1110.0
# 72                       770.0        2954.0
# 21                       364.0        5409.0
# 49                       520.0        5797.0
# 32                       567.0        6848.0

# %%
sns.set(rc = {'figure.figsize':(6,10)}, font_scale = 8)
sns.set_theme(style="ticks")
ie = sns.barplot(data = central_least_5, y = 'Location', x = 'Total cycles')
ie.set_title('Central', fontsize = 30)
#ie.set_xlabel('Location', fontsize = 20)
#ie.set_ylabel('Total Cycles', fontsize = 20)
ie.set(ylabel=None)
plt.xticks(fontsize=15)
plt.yticks(fontsize=20, rotation = 50)
for i in ie.containers:
    ie.bar_label(i,)


plt.savefig('Top 5 East West Roads with Least Cycle in Central London.png', bbox_inches = 'tight', transparent = True)

# %%
central_east_west['Year'].unique()
# Out:
# array(['2014', '2015', nan, '2016', '2017', '2018', '2019', '2020',
#        '2021'], dtype=object)

# %%
belvedere = central_east_west[central_east_west['Location'] == 'Belvedere Road']

belvedere.shape
# Out:
# (128, 17)

# %%
sns.lineplot(data = belvedere, x = 'Year', y = 'Total cycles')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total cycles'>

# %%
stanhope = central_east_west[central_east_west['Location'] == 'Stanhope Gate']

stanhope.shape
# Out:
# (3712, 17)

# %%
stanhope.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3712 entries, 21888 to 753554
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Survey wave (calendar quarter)  3712 non-null   object
#  1   Equivalent financial quarter    3712 non-null   object
#  2   Site ID                         3712 non-null   object
#  3   Location                        3712 non-null   object
#  4   Survey date                     3712 non-null   object
#  5   Weather                         3712 non-null   object
#  6   Time                            3712 non-null   object
#  7   Period                          3712 non-null   object
#  8   Direction                       3712 non-null   object
#  9   Start hour                      3712 non-null   float64
#  10  Start minute                    3712 non-null   float64
#  11  Number of private cycles        3712 non-null   float64
# ...

# %%
sns.lineplot(data = stanhope, x = 'Year', y = 'Total cycles', ci = None)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total cycles'>

# %%
eagle = central_east_west[central_east_west['Location'] == 'Eagle Street']

eagle.shape
# Out:
# (3712, 17)

# %%
sns.lineplot(data = eagle, x = 'Year', y = 'Total cycles', ci = None)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total cycles'>

# %% [markdown]
# # Outer London - Location

# %%
# Add new column
outer_df['Area'] = 'Outer'

# %%
# View dataframe
outer_df.head()
# Out:
#    Survey wave (year)   Site ID          Location    Survey date Weather  \
# 0                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 1                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 2                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 3                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 4                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
#
#           Time                       Period   Direction  Start hour  \
# 0  0600 - 0615  Early Morning (06:00-07:00)  Northbound           6
# 1  0615 - 0630  Early Morning (06:00-07:00)  Northbound           6
# 2  0630 - 0645  Early Morning (06:00-07:00)  Northbound           6
# 3  0645 - 0700  Early Morning (06:00-07:00)  Northbound           6
# 4  0700 - 0715        AM peak (07:00-10:00)  Northbound           7
#
#    Start minute  Number of male cycles  Number of female cycles  \
# ...

# %%
# View data type
outer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375660 entries, 0 to 375659
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Survey wave (year)        375660 non-null  int64
#  1   Site ID                   375660 non-null  object
#  2   Location                  375660 non-null  object
#  3   Survey date               374492 non-null  object
#  4   Weather                   374692 non-null  object
#  5   Time                      375660 non-null  object
#  6   Period                    375660 non-null  object
#  7   Direction                 375660 non-null  object
#  8   Start hour                375660 non-null  int64
#  9   Start minute              375660 non-null  int64
#  10  Number of male cycles     375660 non-null  int64
#  11  Number of female cycles   375660 non-null  int64
#  12  Number of unknown cycles  375660 non-null  int64
# ...

# %%
# View missing values
outer_df.isna().sum()
# Out:
# Survey wave (year)             0
# Site ID                        0
# Location                       0
# Survey date                 1168
# Weather                      968
# Time                           0
# Period                         0
# Direction                      0
# Start hour                     0
# Start minute                   0
# Number of male cycles          0
# Number of female cycles        0
# Number of unknown cycles       0
# Total cycles                   0
# dtype: int64

# %%
# View descriptive statistics
outer_df.describe().round()
# Out:
#        Survey wave (year)  Start hour  Start minute  Number of male cycles  \
# count            375660.0    375660.0      375660.0               375660.0
# mean               2018.0        13.0          22.0                    1.0
# std                   2.0         5.0          17.0                    3.0
# min                2015.0         6.0           0.0                    0.0
# 25%                2016.0         9.0           0.0                    0.0
# 50%                2018.0        13.0          15.0                    0.0
# 75%                2019.0        17.0          30.0                    2.0
# max                2021.0        21.0          45.0                   62.0
#
#        Number of female cycles  Number of unknown cycles  Total cycles
# count                 375660.0                  375660.0      375660.0
# mean                       0.0                       0.0           2.0
# std                        1.0                       0.0           3.0
# ...

# %%
# Group total cycles by direction
outer_direction = outer_df.groupby(['Direction']).sum().reset_index().copy()

outer_direction
# Out:
#     Direction  Survey wave (year)  Start hour  Start minute  \
# 0   Eastbound           176278976     1179360       1965600
# 1  Northbound           202733464     1356278       2260545
# 2  Southbound           202733464     1356278       2260545
# 3   Westbound           176278976     1179360       1965600
#
#    Number of male cycles  Number of female cycles  Number of unknown cycles  \
# 0                 115788                    21934                      1137
# 1                 133827                    22846                      1520
# 2                 134844                    22832                      1409
# 3                 117125                    22789                      1132
#
#    Total cycles
# 0        138859
# 1        158195
# 2        159085
# 3        141046

# %%
d = sns.barplot(data = outer_direction, x = 'Direction', y = 'Total cycles')
d.set_title('Total Cycles categories by direction - Outer London', fontsize = 20)
d.set_xlabel('Area', fontsize = 20)
d.set_ylabel('Total Cycles', fontsize = 20)

plt.savefig('Total Cycles categories by direction - Outer London.png')

# %% [markdown]
# ## Outer East London

# %%
outer_east = outer_df[outer_df['Direction'] == 'Eastbound']

outer_east.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87360 entries, 256 to 375467
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Survey wave (year)        87360 non-null  int64
#  1   Site ID                   87360 non-null  object
#  2   Location                  87360 non-null  object
#  3   Survey date               87296 non-null  object
#  4   Weather                   87284 non-null  object
#  5   Time                      87360 non-null  object
#  6   Period                    87360 non-null  object
#  7   Direction                 87360 non-null  object
#  8   Start hour                87360 non-null  int64
#  9   Start minute              87360 non-null  int64
#  10  Number of male cycles     87360 non-null  int64
#  11  Number of female cycles   87360 non-null  int64
#  12  Number of unknown cycles  87360 non-null  int64
# ...

# %%
# Outer london
outer_east_loc = outer_east.groupby(['Location'])[['Number of male cycles','Number of female cycles','Number of unknown cycles','Total cycles']].sum().reset_index().sort_values('Total cycles', ascending = True)

print(outer_east_loc.shape)

outer_east_loc_10 = outer_east_loc.head(10)

outer_east_loc_10
# Out:
# (210, 5)
#                            Location  Number of male cycles  \
# 58                    Culloden Road                      8
# 102  Harrow Weald Recreation Ground                      7
# 11                        Avon Road                     20
# 132        Newton Farm Ecology Park                     20
# 109                Jim O'Neill Walk                     19
# 206                 Woolwich Common                     21
# 31                  Broadwater Lane                     21
# 127                   Mowbrays Road                     29
# 97                  Grovelands Road                     26
# 198                      Willet Way                     32
#
#      Number of female cycles  Number of unknown cycles  Total cycles
# 58                         3                         0            11
# 102                        4                         0            11
# 11                         3                         0            23
# ...

# %%
sns.set(rc = {'figure.figsize':(20,10)}, font_scale = 8)
sns.set_theme(style="ticks")
ie = sns.barplot(data = outer_east_loc_10, x = 'Location', y = 'Total cycles')
ie.set_title('Top 10 Roads with Least Cycles in Outer East London', fontsize = 40)
ie.set_xlabel('Location', fontsize = 20)
ie.set_ylabel('Total Cycles', fontsize = 20)
plt.xticks(rotation=20, fontsize=15)
plt.yticks(fontsize=20)
for i in ie.containers:
    ie.bar_label(i,)


plt.savefig('Top 10 Roads with Least Cycle in Outer East.png')

# %% [markdown]
# ## Outer West London

# %%
outer_west = outer_df[outer_df['Direction'] == 'Westbound']

outer_west.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87360 entries, 320 to 375531
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Survey wave (year)        87360 non-null  int64
#  1   Site ID                   87360 non-null  object
#  2   Location                  87360 non-null  object
#  3   Survey date               87296 non-null  object
#  4   Weather                   87284 non-null  object
#  5   Time                      87360 non-null  object
#  6   Period                    87360 non-null  object
#  7   Direction                 87360 non-null  object
#  8   Start hour                87360 non-null  int64
#  9   Start minute              87360 non-null  int64
#  10  Number of male cycles     87360 non-null  int64
#  11  Number of female cycles   87360 non-null  int64
#  12  Number of unknown cycles  87360 non-null  int64
# ...

# %%
# Outer london
outer_west_loc = outer_west.groupby(['Location'])[['Number of male cycles','Number of female cycles','Number of unknown cycles','Total cycles']].sum().reset_index().sort_values('Total cycles', ascending = True)

print(outer_west_loc.shape)

outer_west_loc_10 = outer_west_loc.head(10)

outer_west_loc_10
# Out:
# (210, 5)
#                            Location  Number of male cycles  \
# 102  Harrow Weald Recreation Ground                      5
# 58                    Culloden Road                     15
# 206                 Woolwich Common                     14
# 97                  Grovelands Road                     20
# 11                        Avon Road                     14
# 116                  Leadale Avenue                     24
# 31                  Broadwater Lane                     21
# 127                   Mowbrays Road                     30
# 198                      Willet Way                     31
# 69                     Epstein Road                     25
#
#      Number of female cycles  Number of unknown cycles  Total cycles
# 102                        0                         0             5
# 58                         2                         0            17
# 206                        4                         0            18
# ...

# %%
sns.set(rc = {'figure.figsize':(20,10)}, font_scale = 8)
sns.set_theme(style="ticks")
ie = sns.barplot(data = outer_west_loc_10, x = 'Location', y = 'Total cycles')
ie.set_title('Top 10 Roads with Least Cycles in Outer West London', fontsize = 40)
ie.set_xlabel('Location', fontsize = 20)
ie.set_ylabel('Total Cycles', fontsize = 20)
plt.xticks(rotation=20, fontsize=15)
plt.yticks(fontsize=20)
for i in ie.containers:
    ie.bar_label(i,)


plt.savefig('Top 10 Roads with Least Cycle in Outer West.png')

# %% [markdown]
# # Outer West & East Total Cycles

# %%
outer_east_west = outer_df[(outer_df['Direction'] == 'Eastbound') | (outer_df['Direction'] == 'Westbound')]

outer_east_west
# Out:
#         Survey wave (year)   Site ID                 Location    Survey date  \
# 256                   2015  OUTCY003                Wood Lane  jeu, 04/06/15
# 257                   2015  OUTCY003                Wood Lane  jeu, 04/06/15
# 258                   2015  OUTCY003                Wood Lane  jeu, 04/06/15
# 259                   2015  OUTCY003                Wood Lane  jeu, 04/06/15
# 260                   2015  OUTCY003                Wood Lane  jeu, 04/06/15
# ...                    ...       ...                      ...            ...
# 375527                2021  OUTCY450  Bushy Park Church Grove  lun, 10/05/21
# 375528                2021  OUTCY450  Bushy Park Church Grove  lun, 10/05/21
# 375529                2021  OUTCY450  Bushy Park Church Grove  lun, 10/05/21
# 375530                2021  OUTCY450  Bushy Park Church Grove  lun, 10/05/21
# 375531                2021  OUTCY450  Bushy Park Church Grove  lun, 10/05/21
#
# ...

# %%
outer_east_west['Direction'].value_counts()
# Out:
# Eastbound    87360
# Westbound    87360
# Name: Direction, dtype: int64

# %%
# Check that same road is east/west direction
harrow = outer_df[outer_df['Location'] == 'Harrow Weald Recreation Ground']

harrow.groupby(['Direction','Location'])[['Number of male cycles','Number of female cycles','Number of unknown cycles','Total cycles']].sum().reset_index().sort_values('Total cycles', ascending = True)
# Out:
#    Direction                        Location  Number of male cycles  \
# 1  Westbound  Harrow Weald Recreation Ground                      5
# 0  Eastbound  Harrow Weald Recreation Ground                      7
#
#    Number of female cycles  Number of unknown cycles  Total cycles
# 1                        0                         0             5
# 0                        4                         0            11

# %%
outer_loc = outer_east_west.groupby(['Location'])[['Number of male cycles','Number of female cycles','Number of unknown cycles','Total cycles']].sum().reset_index().sort_values('Total cycles', ascending = True)

outer_least_5 = outer_loc.head(5)

outer_least_5
# Out:
#                            Location  Number of male cycles  \
# 102  Harrow Weald Recreation Ground                     12
# 58                    Culloden Road                     23
# 206                 Woolwich Common                     35
# 11                        Avon Road                     34
# 97                  Grovelands Road                     46
#
#      Number of female cycles  Number of unknown cycles  Total cycles
# 102                        4                         0            16
# 58                         5                         0            28
# 206                        6                         5            46
# 11                        15                         0            49
# 97                         7                         0            53

# %%
sns.set(rc = {'figure.figsize':(6,10)}, font_scale = 8)
sns.set_theme(style="ticks")
ie = sns.barplot(data = outer_least_5, y = 'Location', x = 'Total cycles')
ie.set_title('Outer', fontsize = 30)
#ie.set_xlabel('Location', fontsize = 20)
#ie.set_ylabel('Total Cycles', fontsize = 20)
ie.set(ylabel=None)
plt.xticks(fontsize=15)
plt.yticks(fontsize=20, rotation = 50)
for i in ie.containers:
    ie.bar_label(i,)


plt.savefig('Top 5 East West Roads with Least Cycle in Outer London.png', bbox_inches = 'tight', transparent = True)

# %%
harrow = outer_east_west[outer_east_west['Location'] == 'Harrow Weald Recreation Ground'].copy()

harrow
# Out:
#         Survey wave (year)   Site ID                        Location  \
# 47744                 2015  OUTCY374  Harrow Weald Recreation Ground
# 47745                 2015  OUTCY374  Harrow Weald Recreation Ground
# 47746                 2015  OUTCY374  Harrow Weald Recreation Ground
# 47747                 2015  OUTCY374  Harrow Weald Recreation Ground
# 47748                 2015  OUTCY374  Harrow Weald Recreation Ground
# ...                    ...       ...                             ...
# 366055                2021  OUTCY374  Harrow Weald Recreation Ground
# 366056                2021  OUTCY374  Harrow Weald Recreation Ground
# 366057                2021  OUTCY374  Harrow Weald Recreation Ground
# 366058                2021  OUTCY374  Harrow Weald Recreation Ground
# 366059                2021  OUTCY374  Harrow Weald Recreation Ground
#
#           Survey date Weather         Time                       Period  \
# ...

# %%
harrow.isna().sum()
# Out:
# Survey wave (year)          0
# Site ID                     0
# Location                    0
# Survey date                 0
# Weather                     0
# Time                        0
# Period                      0
# Direction                   0
# Start hour                  0
# Start minute                0
# Number of male cycles       0
# Number of female cycles     0
# Number of unknown cycles    0
# Total cycles                0
# dtype: int64

# %%
harrow['Survey wave (year)'] = harrow['Survey wave (year)'].astype(str)

# %%
sns.lineplot(data = harrow, x = 'Survey wave (year)', y = 'Total cycles', ci = None)
# Out:
# <AxesSubplot:xlabel='Survey wave (year)', ylabel='Total cycles'>

# %% [markdown]
# # Total Cycles in Inner & Outer & Central

# %%
direction_c_i = direction[['Area','Direction','Total cycles']]

direction_c_i
# Out:
#       Area   Direction  Total cycles
# 0  Central   Eastbound     2914119.0
# 1  Central  Northbound     3471866.0
# 2  Central  Southbound     3269824.0
# 3  Central   Westbound     2969910.0
# 4    Inner   Eastbound      688735.0
# 5    Inner  Northbound      926529.0
# 6    Inner  Southbound      932491.0
# 7    Inner   Westbound      697775.0

# %%
outer_group = outer_df.groupby(['Area','Direction']).sum().reset_index()

direction_o = outer_group[['Area','Direction','Total cycles']]

direction_o
# Out:
#     Area   Direction  Total cycles
# 0  Outer   Eastbound        138859
# 1  Outer  Northbound        158195
# 2  Outer  Southbound        159085
# 3  Outer   Westbound        141046

# %%
# Concatente data and reset index
total_cycles = pd.concat([direction_c_i, direction_o], ignore_index = True)

total_cycles
# Out:
#        Area   Direction  Total cycles
# 0   Central   Eastbound     2914119.0
# 1   Central  Northbound     3471866.0
# 2   Central  Southbound     3269824.0
# 3   Central   Westbound     2969910.0
# 4     Inner   Eastbound      688735.0
# 5     Inner  Northbound      926529.0
# 6     Inner  Southbound      932491.0
# 7     Inner   Westbound      697775.0
# 8     Outer   Eastbound      138859.0
# 9     Outer  Northbound      158195.0
# 10    Outer  Southbound      159085.0
# 11    Outer   Westbound      141046.0

# %%
sns.set(rc = {'figure.figsize':(13,8)}, font_scale = 8)
sns.set_theme(style="ticks")
d = sns.barplot(data = total_cycles, x = 'Area', y = 'Total cycles', hue = 'Direction')
d.set_title('Total Cycles split by direction', fontsize = 20)
#d.set_xlabel('Area', fontsize = 20)
d.set_ylabel('Total Cycles (M)', fontsize = 20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
d.set(xlabel=None)
for i in ie.containers:
    ie.bar_label(i,)

plt.savefig('Total Cycles by direction all.png', transparent = True, bbox_inches = 'tight')
