# %% [markdown]
# # Q1. What are the main factors determining when people cycle?

# %% [markdown]
# # Investigation into time of year, time of day, weather, direction of travel

# %% [markdown]
# ## Prepare workstation and import files

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Rationale for libraries and packages:
# - Numpy: used for statistical calculations
# - Pandas: used for data manipulation and analysis
# - Matplotlib: used for plotting functions
# - Seaborn: used for plotting functions

# %%
# Turn off warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Rationale: Warning usually occur when there are obsolete programming elements. Warnings have been turned off to make
# the code cleaner. However, this will still allow errors to appear.

# %%
# Import data files
central_london = pd.read_csv("Central London.csv")
inner_london = pd.read_csv("Inner London.csv")
outer_london = pd.read_csv("Outer London.csv")

# %% [markdown]
# ## Explore and clean raw data

# %% [markdown]
# ### Central London

# %%
# Print shape
print(central_london.shape)
# Out:
# (1048366, 17)

# %%
# Examine columns
print(central_london.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048366 entries, 0 to 1048365
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Survey wave (calendar quarter)  758163 non-null  object
#  1   Equivalent financial quarter    758163 non-null  object
#  2   Site ID                         758163 non-null  object
#  3   Location                        758163 non-null  object
#  4   Survey date                     748007 non-null  object
#  5   Weather                         746329 non-null  object
#  6   Time                            758163 non-null  object
#  7   Period                          758163 non-null  object
#  8   Direction                       758163 non-null  object
#  9   Start hour                      758163 non-null  float64
#  10  Start minute                    758163 non-null  float64
#  11  Number of private cycles        758099 non-null  float64
#  12  Number of cycle hire bikes      758099 non-null  float64
#  13  Total cycles                    758163 non-null  float64
#  14  Unnamed: 14                     0 non-null       float64
#  15  Unnamed: 15                     0 non-null       float64
#  16  Unnamed: 16                     0 non-null       float64
# dtypes: float64(8), object(9)
# memory usage: 136.0+ MB
# None

# %%
# Check for missing values
print(central_london.isnull().sum())
# Out:
# Survey wave (calendar quarter)     290203
# Equivalent financial quarter       290203
# Site ID                            290203
# Location                           290203
# Survey date                        300359
# Weather                            302037
# Time                               290203
# Period                             290203
# Direction                          290203
# Start hour                         290203
# Start minute                       290203
# Number of private cycles           290267
# Number of cycle hire bikes         290267
# Total cycles                       290203
# Unnamed: 14                       1048366
# Unnamed: 15                       1048366
# Unnamed: 16                       1048366
# dtype: int64

# %%
# Print values for Survey wave (calendar quarter)
central_london['Survey wave (calendar quarter)'].value_counts()
# Out:
# 2020 Q3 (July-September)       26880
# 2020 Q1 (January-March)        26880
# 2019 Q2 (April-June)           26880
# 2019 Q1 (January-March)        26880
# 2018 Q4 (October-December)     26880
# 2018 Q3 (July-September)       26880
# 2018 Q2 (April-June)           26880
# 2017 Q4 (October-December)     26752
# 2017 Q3 (July-September)       26752
# 2019 Q4 (October-December)     26752
# 2019 Q3 (July-September)       26752
# 2021 Q4 (October-December)     26624
# 2021 Q3 (July-September)       26584
# 2017 Q1 (January-March)        25728
# 2015 Q4 (October-December)     25728
# 2014 Q3 (July-September)       25728
# 2014 Q4 (October-December)     25728
# 2015 Q1 (January-March)        25728
# 2015 Q2 (April-June)           25728
# 2017 Q2 (April-June)           25728
# 2015 Q3 (July-September)       25728
# 2016 Q2 (April-June)           25728
# 2018 Q1 (January-March)        25728
# 2014 Q2 (April-June)           25728
# 2016 Q4 (October-December)     25728
# 2016 Q1 (January-March)        25600
# 2016 Q3 (July-September)       25600
# 2014 Q1 (January-March)        25408
# 2021 Q2 (April-June)           12281
# 2021 Q2 (April-June)           12034
# 2021 Q3 (July-September)         128
# Name: Survey wave (calendar quarter), dtype: int64

# %%
# Drop unnamed columns from data frame
central_london_clean = central_london.drop(['Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'], axis=1)
print(central_london_clean.head())
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
# 2                      35.0                         0.0          35.0
# 3                      59.0                         2.0          61.0
# 4                      73.0                         0.0          73.0

# %%
# Create Month column
central_london_clean['Month'] = central_london_clean['Survey date'].str.split('/').str[1]

# %%
# Check values of new Month column
print(central_london_clean['Month'].shape)
print(central_london_clean['Month'].value_counts())
print(central_london_clean['Month'].isnull().sum())
# Out:
# (1048366,)
# 11    77101
# 09    76192
# 01    71934
# 08    69512
# 06    67257
# 07    60838
# 03    58606
# 05    56326
# 12    55862
# 02    51936
# 04    51132
# 10    51055
# Name: Month, dtype: int64
# 300615

# %%
# Examine what Survey date looks like when Month is missing but Survey date is not
sub_df = central_london_clean[central_london_clean['Month'].isnull() & ~ central_london_clean['Survey date'].isnull()]
print(sub_df['Survey date'])
# Out:
# 654784
# 654785
# 654786
# 654787
# 654788
#          ..
# 664251
# 664252
# 664253
# 664254
# 664255
# Name: Survey date, Length: 256, dtype: object

# %% [markdown]
# Observations: There are 256 survey date variables that are formatted incorrectly, thus resulting in 256 missing Month values. Given the large size of the data set, these values will be ignored rather than fixing them.

# %%
# Create Year column
central_london_clean['Year'] = central_london_clean['Survey date'].str.split('/').str[2]

# %%
# Check values of new Year column
print(central_london_clean['Year'].shape)
print(central_london_clean['Year'].value_counts())
print(central_london_clean['Year'].isnull().sum())
# Out:
# (1048366,)
# 19    106880
# 18    105300
# 14    102540
# 17    102444
# 16    101632
# 15    100916
# 21     77651
# 20     50388
# Name: Year, dtype: int64
# 300615

# %%
# Create quarter column
central_london_clean['Quarter'] = central_london_clean['Survey wave (calendar quarter)'].str.split(" ").str[1]

# %%
# Check values of new Quarter column
print(central_london_clean['Quarter'].shape)
print(central_london_clean['Quarter'].value_counts())
print(central_london_clean['Quarter'].isnull().sum())
# Out:
# (1048366,)
# Q3    211032
# Q4    184192
# Q1    181952
# Q2    180987
# Name: Quarter, dtype: int64
# 290203

# %%
# Check dtype of new variables
central_london_clean.dtypes
# Out:
# Survey wave (calendar quarter)     object
# Equivalent financial quarter       object
# Site ID                            object
# Location                           object
# Survey date                        object
# Weather                            object
# Time                               object
# Period                             object
# Direction                          object
# Start hour                        float64
# Start minute                      float64
# Number of private cycles          float64
# Number of cycle hire bikes        float64
# Total cycles                      float64
# Month                              object
# Year                               object
# Quarter                            object
# dtype: object

# %%
# Change Month and Year to float
central_london_clean['Month'] = central_london_clean['Month'].astype(float)
central_london_clean['Year'] = central_london_clean['Year'].astype(float)
print(central_london_clean.dtypes)
# Out:
# Survey wave (calendar quarter)     object
# Equivalent financial quarter       object
# Site ID                            object
# Location                           object
# Survey date                        object
# Weather                            object
# Time                               object
# Period                             object
# Direction                          object
# Start hour                        float64
# Start minute                      float64
# Number of private cycles          float64
# Number of cycle hire bikes        float64
# Total cycles                      float64
# Month                             float64
# Year                              float64
# Quarter                            object
# dtype: object

# %%
# Create Region column
central_london_clean['Region'] = "Central London"

# %%
# Check values of new Region column
central_london_clean['Region'].value_counts()
# Out:
# Central London    1048366
# Name: Region, dtype: int64

# %% [markdown]
# ### Outer London

# %%
# Print shape
print(outer_london.shape)
# Out:
# (375660, 14)

# %%
# Examine first few rows of data
print(outer_london.head())
# Out:
#    Survey wave (year)   Site ID          Location    Survey date Weather  \
# 0                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 1                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 2                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 3                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 4                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
#
#           Time                       Period   Direction  Start hour  \
# 0  0600 - 0615  Early Morning (06:00-07:00)  Northbound           6
# 1  0615 - 0630  Early Morning (06:00-07:00)  Northbound           6
# 2  0630 - 0645  Early Morning (06:00-07:00)  Northbound           6
# 3  0645 - 0700  Early Morning (06:00-07:00)  Northbound           6
# 4  0700 - 0715        AM peak (07:00-10:00)  Northbound           7
#
#    Start minute  Number of male cycles  Number of female cycles  \
# 0             0                      2                        1
# 1            15                      3                        0
# 2            30                      2                        0
# 3            45                      4                        0
# 4             0                      4                        1
#
#    Number of unknown cycles  Total cycles
# 0                         0             3
# 1                         0             3
# 2                         0             2
# 3                         0             4
# 4                         0             5

# %%
# Examine columns
print(outer_london.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375660 entries, 0 to 375659
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Survey wave (year)        375660 non-null  int64
#  1   Site ID                   375660 non-null  object
#  2   Location                  375660 non-null  object
#  3   Survey date               374492 non-null  object
#  4   Weather                   374692 non-null  object
#  5   Time                      375660 non-null  object
#  6   Period                    375660 non-null  object
#  7   Direction                 375660 non-null  object
#  8   Start hour                375660 non-null  int64
#  9   Start minute              375660 non-null  int64
#  10  Number of male cycles     375660 non-null  int64
#  11  Number of female cycles   375660 non-null  int64
#  12  Number of unknown cycles  375660 non-null  int64
#  13  Total cycles              375660 non-null  int64
# dtypes: int64(7), object(7)
# memory usage: 40.1+ MB
# None

# %%
# Check for missing values
print(outer_london.isnull().sum())
# Out:
# Survey wave (year)             0
# Site ID                        0
# Location                       0
# Survey date                 1168
# Weather                      968
# Time                           0
# Period                         0
# Direction                      0
# Start hour                     0
# Start minute                   0
# Number of male cycles          0
# Number of female cycles        0
# Number of unknown cycles       0
# Total cycles                   0
# dtype: int64

# %%
# Create Month column
outer_london['Month'] = outer_london['Survey date'].str.split('/').str[1]

# %%
# Check values of new Month column
print(outer_london['Month'].shape)
print(outer_london['Month'].value_counts())
print(outer_london['Month'].isnull().sum())
# Out:
# (375660,)
# 06    125316
# 05    116664
# 04     54884
# 07     46768
# 10     16992
# 09     13580
# 08       160
# 11       128
# Name: Month, dtype: int64
# 1168

# %%
# Create Year column
outer_london['Year'] = outer_london['Survey date'].str.split('/').str[2]

# %%
# Check values of new Year column
print(outer_london['Year'].shape)
print(outer_london['Year'].value_counts())
print(outer_london['Year'].isnull().sum())
# Out:
# (375660,)
# 18    57728
# 19    57584
# 21    57472
# 15    57344
# 16    57344
# 17    57344
# 20    29676
# Name: Year, dtype: int64
# 1168

# %%
# Check dtypes
outer_london.dtypes
# Out:
# Survey wave (year)           int64
# Site ID                     object
# Location                    object
# Survey date                 object
# Weather                     object
# Time                        object
# Period                      object
# Direction                   object
# Start hour                   int64
# Start minute                 int64
# Number of male cycles        int64
# Number of female cycles      int64
# Number of unknown cycles     int64
# Total cycles                 int64
# Month                       object
# Year                        object
# dtype: object

# %%
# Change Month and Year to float
outer_london['Month'] = outer_london['Month'].astype(float)
outer_london['Year'] = outer_london['Year'].astype(float)
print(outer_london.dtypes)
# Out:
# Survey wave (year)            int64
# Site ID                      object
# Location                     object
# Survey date                  object
# Weather                      object
# Time                         object
# Period                       object
# Direction                    object
# Start hour                    int64
# Start minute                  int64
# Number of male cycles         int64
# Number of female cycles       int64
# Number of unknown cycles      int64
# Total cycles                  int64
# Month                       float64
# Year                        float64
# dtype: object

# %%
# Create a Quarter column

# Create list of conditions
conditions = [
    (outer_london['Month'] > 0) & (outer_london['Month'] <= 3),
    (outer_london['Month'] > 3) & (outer_london['Month'] <= 6),
    (outer_london['Month'] > 6) & (outer_london['Month'] <= 9),
    (outer_london['Month'] > 9) & (outer_london['Month'] <= 12)
]

# Create a list of values to assign for each condition
values = ['Q1', 'Q2', 'Q3', 'Q4']

# Create new 'Seasons' column and use np.select to assign values to it
outer_london['Quarter'] = np.select(conditions, values)

# Display updated DataFrame
print(outer_london.Quarter.value_counts())
print(outer_london.head())
print(outer_london.tail())
# Out:
# Q2    296864
# Q3     60508
# Q4     17120
# 0       1168
# Name: Quarter, dtype: int64
#    Survey wave (year)   Site ID          Location    Survey date Weather  \
# 0                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 1                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 2                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 3                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 4                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
#
#           Time                       Period   Direction  Start hour  \
# 0  0600 - 0615  Early Morning (06:00-07:00)  Northbound           6
# 1  0615 - 0630  Early Morning (06:00-07:00)  Northbound           6
# 2  0630 - 0645  Early Morning (06:00-07:00)  Northbound           6
# 3  0645 - 0700  Early Morning (06:00-07:00)  Northbound           6
# 4  0700 - 0715        AM peak (07:00-10:00)  Northbound           7
#
#    Start minute  Number of male cycles  Number of female cycles  \
# 0             0                      2                        1
# 1            15                      3                        0
# 2            30                      2                        0
# 3            45                      4                        0
# 4             0                      4                        1
#
#    Number of unknown cycles  Total cycles  Month  Year Quarter
# 0                         0             3    6.0  15.0      Q2
# 1                         0             3    6.0  15.0      Q2
# 2                         0             2    6.0  15.0      Q2
# 3                         0             4    6.0  15.0      Q2
# 4                         0             5    6.0  15.0      Q2
#         Survey wave (year)   Site ID                      Location  \
# 375655                2021  OUTCY451  Thames Path (Lower Ham Road)
# 375656                2021  OUTCY451  Thames Path (Lower Ham Road)
# 375657                2021  OUTCY451  Thames Path (Lower Ham Road)
# 375658                2021  OUTCY451  Thames Path (Lower Ham Road)
# 375659                2021  OUTCY451  Thames Path (Lower Ham Road)
#
#           Survey date Weather         Time                 Period   Direction  \
# 375655  ven, 18/06/21     Wet  2045 - 2100  Evening (19:00-22:00)  Southbound
# 375656  ven, 18/06/21     Wet  2100 - 2115  Evening (19:00-22:00)  Southbound
# 375657  ven, 18/06/21     Wet  2115 - 2130  Evening (19:00-22:00)  Southbound
# 375658  ven, 18/06/21     Wet  2130 - 2145  Evening (19:00-22:00)  Southbound
# 375659  ven, 18/06/21     Wet  2145 - 2200  Evening (19:00-22:00)  Southbound
#
#         Start hour  Start minute  Number of male cycles  \
# 375655          20            45                      1
# 375656          21             0                      2
# 375657          21            15                      0
# 375658          21            30                      0
# 375659          21            45                      1
#
#         Number of female cycles  Number of unknown cycles  Total cycles  \
# 375655                        0                         0             1
# 375656                        0                         0             2
# 375657                        0                         0             0
# 375658                        0                         0             0
# 375659                        0                         0             1
#
#         Month  Year Quarter
# 375655    6.0  21.0      Q2
# 375656    6.0  21.0      Q2
# 375657    6.0  21.0      Q2
# 375658    6.0  21.0      Q2
# 375659    6.0  21.0      Q2

# %%
# Create Region column
outer_london['Region'] = "Outer London"

# %%
# Check Region column
outer_london['Region'].value_counts()
# Out:
# Outer London    375660
# Name: Region, dtype: int64

# %% [markdown]
# ### Inner London

# %%
# Print shape
print(inner_london.shape)
# Out:
# (615168, 13)

# %%
# Examine first few rows of data
print(inner_london.head())
# Out:
#    Survey wave (year)   Site ID    Location    Survey date Weather  \
# 0              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 1              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 2              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 3              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 4              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
#
#           Time                       Period   Direction  Start hour  \
# 0  0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1  0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
# 2  0630 - 0645  Early Morning (06:00-07:00)  Northbound         6.0
# 3  0645 - 0700  Early Morning (06:00-07:00)  Northbound         6.0
# 4  0700 - 0715        AM peak (07:00-10:00)  Northbound         7.0
#
#    Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0           0.0                       1.0                         0.0
# 1          15.0                       2.0                         0.0
# 2          30.0                       2.0                         0.0
# 3          45.0                       4.0                         0.0
# 4           0.0                       4.0                         0.0
#
#    Total cycles
# 0           1.0
# 1           2.0
# 2           2.0
# 3           4.0
# 4           4.0

# %%
# Examine columns
print(inner_london.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615168 entries, 0 to 615167
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Survey wave (year)          523776 non-null  float64
#  1   Site ID                     523776 non-null  object
#  2   Location                    523776 non-null  object
#  3   Survey date                 521024 non-null  object
#  4   Weather                     519102 non-null  object
#  5   Time                        523770 non-null  object
#  6   Period                      523770 non-null  object
#  7   Direction                   523776 non-null  object
#  8   Start hour                  523770 non-null  float64
#  9   Start minute                523770 non-null  float64
#  10  Number of private cycles    523776 non-null  float64
#  11  Number of cycle hire bikes  523776 non-null  float64
#  12  Total cycles                523776 non-null  float64
# dtypes: float64(6), object(7)
# memory usage: 61.0+ MB
# None

# %%
# Check for missing values
print(inner_london.isnull().sum())
# Out:
# Survey wave (year)            91392
# Site ID                       91392
# Location                      91392
# Survey date                   94144
# Weather                       96066
# Time                          91398
# Period                        91398
# Direction                     91392
# Start hour                    91398
# Start minute                  91398
# Number of private cycles      91392
# Number of cycle hire bikes    91392
# Total cycles                  91392
# dtype: int64

# %%
# Create Month column
inner_london['Month'] = inner_london['Survey date'].str.split('/').str[1]

# %%
# Check values of new Month column
print(inner_london['Month'].shape)
print(inner_london['Month'].value_counts())
print(inner_london['Month'].isnull().sum())
# Out:
# (615168,)
# 06    149524
# 05    149140
# 07     89840
# 04     81278
# 09     26338
# 10     23902
# 11       704
# 08       208
# 03        90
# Name: Month, dtype: int64
# 94144

# %%
# Create Year column
inner_london['Year'] = inner_london['Survey date'].str.split('/').str[2]

# %%
# Check values of new Year column
print(inner_london['Year'].shape)
print(inner_london['Year'].value_counts())
print(inner_london['Year'].isnull().sum())
# Out:
# (615168,)
# 21    91392
# 15    76032
# 16    76032
# 18    76032
# 19    75968
# 17    75264
# 20    50304
# Name: Year, dtype: int64
# 94144

# %%
# Check dtypes
inner_london.dtypes
# Out:
# Survey wave (year)            float64
# Site ID                        object
# Location                       object
# Survey date                    object
# Weather                        object
# Time                           object
# Period                         object
# Direction                      object
# Start hour                    float64
# Start minute                  float64
# Number of private cycles      float64
# Number of cycle hire bikes    float64
# Total cycles                  float64
# Month                          object
# Year                           object
# dtype: object

# %%
# Change Month and Year to float
inner_london['Month'] = inner_london['Month'].astype(float)
inner_london['Year'] = inner_london['Year'].astype(float)
print(inner_london.dtypes)
# Out:
# Survey wave (year)            float64
# Site ID                        object
# Location                       object
# Survey date                    object
# Weather                        object
# Time                           object
# Period                         object
# Direction                      object
# Start hour                    float64
# Start minute                  float64
# Number of private cycles      float64
# Number of cycle hire bikes    float64
# Total cycles                  float64
# Month                         float64
# Year                          float64
# dtype: object

# %%
# Create a Quarter column

# Create list of conditions
conditions = [
    (inner_london['Month'] > 0) & (inner_london['Month'] <= 3),
    (inner_london['Month'] > 3) & (inner_london['Month'] <= 6),
    (inner_london['Month'] > 6) & (inner_london['Month'] <= 9),
    (inner_london['Month'] > 9) & (inner_london['Month'] <= 12)
]

# Create a list of values to assign for each condition
values = ['Q1', 'Q2', 'Q3', 'Q4']

# Create new 'Seasons' column and use np.select to assign values to it
inner_london['Quarter'] = np.select(conditions, values)

# Display updated DataFrame
print(inner_london.Quarter.value_counts())
print(inner_london.head())
print(inner_london.tail())
# Out:
# Q2    379942
# Q3    116386
# 0      94144
# Q4     24606
# Q1        90
# Name: Quarter, dtype: int64
#    Survey wave (year)   Site ID    Location    Survey date Weather  \
# 0              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 1              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 2              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 3              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 4              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
#
#           Time                       Period   Direction  Start hour  \
# 0  0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1  0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
# 2  0630 - 0645  Early Morning (06:00-07:00)  Northbound         6.0
# 3  0645 - 0700  Early Morning (06:00-07:00)  Northbound         6.0
# 4  0700 - 0715        AM peak (07:00-10:00)  Northbound         7.0
#
#    Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0           0.0                       1.0                         0.0
# 1          15.0                       2.0                         0.0
# 2          30.0                       2.0                         0.0
# 3          45.0                       4.0                         0.0
# 4           0.0                       4.0                         0.0
#
#    Total cycles  Month  Year Quarter
# 0           1.0    5.0  15.0      Q2
# 1           2.0    5.0  15.0      Q2
# 2           2.0    5.0  15.0      Q2
# 3           4.0    5.0  15.0      Q2
# 4           4.0    5.0  15.0      Q2
#         Survey wave (year) Site ID Location Survey date Weather Time Period  \
# 615163                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
# 615164                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
# 615165                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
# 615166                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
# 615167                 NaN     NaN      NaN         NaN     NaN  NaN    NaN
#
#        Direction  Start hour  Start minute  Number of private cycles  \
# 615163       NaN         NaN           NaN                       NaN
# 615164       NaN         NaN           NaN                       NaN
# 615165       NaN         NaN           NaN                       NaN
# 615166       NaN         NaN           NaN                       NaN
# 615167       NaN         NaN           NaN                       NaN
#
#         Number of cycle hire bikes  Total cycles  Month  Year Quarter
# 615163                         NaN           NaN    NaN   NaN       0
# 615164                         NaN           NaN    NaN   NaN       0
# 615165                         NaN           NaN    NaN   NaN       0
# 615166                         NaN           NaN    NaN   NaN       0
# 615167                         NaN           NaN    NaN   NaN       0

# %%
# Create Region column
inner_london['Region'] = "Inner London"

# %%
# Check Region column
inner_london['Region'].value_counts()
# Out:
# Inner London    615168
# Name: Region, dtype: int64

# %% [markdown]
# ### Concatenate data

# %%
# Concatenate data and reset index
london_all = pd.concat([central_london_clean, inner_london, outer_london], ignore_index=True)

# %%
# Examine shape of new data
print(london_all.shape)
# Out:
# (2039194, 22)

# %%
# Examine missing values
london_all.isnull().sum()
# Out:
# Survey wave (calendar quarter)    1281031
# Equivalent financial quarter      1281031
# Site ID                            381595
# Location                           381595
# Survey date                        395671
# Weather                            399071
# Time                               381601
# Period                             381601
# Direction                          381595
# Start hour                         381601
# Start minute                       381601
# Number of private cycles           757319
# Number of cycle hire bikes         757319
# Total cycles                       381595
# Month                              395927
# Year                               395927
# Quarter                            290203
# Region                                  0
# Survey wave (year)                1139758
# Number of male cycles             1663534
# Number of female cycles           1663534
# Number of unknown cycles          1663534
# dtype: int64

# %% [markdown]
# ### Examine values of columns of interest

# %%
# View all rows
pd.set_option('display.max_rows', None)

# %%
# Values for 'Weather'
london_all['Weather'].value_counts()
# Out:
# Dry                                1378499
# Wet                                 175489
# Fine                                 21786
# Sunny                                11952
# Cloudy                               10366
# Rain                                  9032
# N/a                                   2560
# Drizzle                               1600
# D                                     1440
# Dry/sunny                             1378
# Light Rain                            1068
# Fair                                  1020
# Damp                                   789
# Unknown                                768
# Cold                                   684
# Dry/wet                                666
# Wet/dry                                656
# Windy                                  534
# Dry & Sunny                            446
# Clear and Warm                         432
# Wet                                    408
# Cold/rain                              384
# Showers                                376
# Wet Road                               366
# Overcast                               342
# Rainy                                  312
# Lt Rain                                304
# Dry/cloudy                             284
# Sun                                    260
# Dry/cold                               260
# Rain/wind                              256
# Good                                   256
# Sun/cloudy                             234
# Dry/hot                                234
# Sunny/cloudy                           230
# Light Showers                          222
# Cloudy/rain                            214
# Hot                                    206
# Sunny/dry                              202
# Clear                                  186
# Clear and Bright                       180
# Very Wet                               180
# Dry/windy                              180
# Dry/good                               160
# Snow                                   150
# V Light Rain                           148
# Warm + Dry                             148
# Cold/dry                               148
# Cloudy/dry                             148
# Heavy Rain                             148
# Dry Wet Road                           146
# Dry & Windy                            144
# Dry/sun                                138
# Dry And Fine                           132
# Rain/cloudy                            130
# Sun/rain                               128
# Cloudy but dry                         128
# Cold/ Rain                             128
# Cloudy with Clear Intervals            128
# Sunny Dry                              128
# Partly Cloudy                          126
# Cloudy/sunny                           124
# Dry And Sunny                          118
# Dry Road Still Wet                     116
# Showery                                104
# Heavy Showers                           96
# Hot And Sunny                           96
# Good/dry                                96
# Cold Dry                                94
# W                                       94
# Overcast/dry                            92
# Raining                                 90
# Cold Windy Dry                          90
# Sun/clouds                              90
# Dry & Mild                              88
# Dry & Wet                               86
# Dry Hot!!                               86
# Wet/windy                               84
# Shower                                  82
# Partly cloudy and Dry                   80
# Cloudy bright intervals                 80
# Dry Sunny                               76
# Dry-wet                                 74
# Hot & Sunny                             74
# Fine + Dry                              72
# Mix Wet/dry                             72
# Wet - Dry                               72
# Dry Windy                               70
# Dry + Wet                               68
# Hot/dry                                 68
# Rain/dry                                66
# Slightly Wet                            66
# Very Hot/dry                            64
# Windy At First Then Sunny               64
# Sunny & Warm All Day                    64
# Dry/drizzly                             64
# Wet-windy                               64
# Partly cloudy and dry                   64
# Cold & Dry Early Rain Later             64
# Partly cloudy but dry                   64
# Rain/sleet                              64
# Dry, Sunny, Warm                        64
# Clear and Dry                           64
# Cloudy/hail                             64
# Wet/v.windy                             64
# Fine Cold                               64
# Fine V Cold                             64
# Fine/dry                                64
# Windy/rain                              64
# Hot + Humid                             64
# Fine & Sunny                            64
# Warm & Sunny Chilly Later               64
# Periods Of Rain Quite Windy             64
# Cold At First Then Warm/sunny           64
# Very Windy & Cold                       64
# Cold Sunny Rain                         64
# Heavy Showers Throughout Day            64
# Intermitent Light Showers               64
# Intermitent Light Rain                  64
# Cold Then Dry And Windy                 64
# Dry And Overcast                        64
# Very Cold Sunny But Windy               64
# Warm & Sunny But Windy & Cold           64
# A Bit Chilly At First                   64
# Fine + Dry Chilly At First              64
# Wet And Windy                           64
# Warm With A Slight Wind                 64
# Cloudy with clear spells                64
# Hazy                                    64
# Cloudy/ Rain                            64
# Some Showers                            64
# Blustery                                64
# Dry A.m Wet P.m                         64
# Windy/ Rain                             64
# Foggy                                   64
# Rain Stopped-dry                        62
# Fine + Hot                              56
# Warm And Humid                          56
# Fine And Dry                            56
# Dry (windy)                             54
# Mild                                    52
# Dry + Sunny                             52
# Dull                                    50
# Cloudy and Dry                          48
# High Wind                               48
# Cold/sunny                              48
# V Wet                                   48
# Warm And Windy                          48
# Rain Damp                               47
# Light Drizzle                           46
# Dry But Rain Threatening                46
# Wet-dry                                 46
# Dry & Cold                              44
# Wet (heavy Rain)                        44
# Dry Warm                                44
# Wet & Windy                             42
# Sunny But Very Windy                    42
# Dry Thu                                 42
# Dry Mon                                 40
# Dry And Very Windy                      40
# Dry But Misty                           40
# Warm Sunny And Windy                    40
# Cloudy with showers                     40
# Hot And Humid                           40
# Mild And Sunny                          40
# V Light Drizzle                         40
# Warm And Overcast                       40
# Light Shrs                              40
# Dryish                                  40
# Drizzling                               40
# Dry (frost & Fog)                       40
# High Winds & Spits Of Rain              38
# Road Wet                                36
# Sunny (hot!)                            36
# Wet Drizzle                             36
# V.wet                                   36
# Bright                                  36
# Generally overcast brief shower         34
# Very Windy                              34
# Foggy/v Cold                            34
# Wet + Windy                             34
# Rain-heavy                              34
# Wet Heavy Wind                          32
# Overcast (No Rain)                      32
# Dry Very Windy                          32
# Sunny/rainy                             32
# Dry With Intermitent Rain               32
# Dry - Wet                               32
# Overcast/rain                           32
# Dry, Sunny, Hot                         32
# Wet Heavy Rain                          32
# Dry But Wet Roads                       32
# Sleet                                   32
# Wet/ Dry                                32
# Very Cool                               32
# Dry But A Bit Windy                     32
# S. Wet                                  32
# Damp & Drizzly                          32
# Dry, Warm                               32
# Sunny Cold                              32
# Dry But Wet Road                        30
# Overcast And Dull                       30
# Spitting                                30
# Windy + Sunny                           30
# Dry/sunny/cold                          28
# Intermittent Light Drizzle              28
# Sunny Until Evening But Windy           28
# Fine & Dry                              28
# Windy Dry                               28
# dry                                     26
# Occasional Lt Snow Shrs                 26
# Wet Intermittently                      26
# Wet/damp                                26
# Dry & Very Windy                        26
# Clouds & Sunny                          26
# Steady Rain                             26
# Dry Cold                                26
# Dry/wet Road                            24
# Dry Dark                                24
# Mizzle                                  24
# Down Pour                               24
# Dry/overcast                            24
# Wet Damp                                24
# Dry And Windy                           24
# Cloudy & Sunny                          24
# Slight Drizzle                          24
# Cloudy And Warm                         24
# Sunny Periods And Warm                  24
# Very Cold/dry                           24
# Dry Wed                                 24
# Cloud                                   22
# Generally overcast                      22
# Now Starts To Get Chilly                22
# 2 Snowflakes Otherwise Dry              22
# Dry/v. Windy                            22
# Dry Fri                                 22
# Wet/rain                                22
# Dry V. Cold!                            22
# Sunny & Windy                           20
# Heavy Snow                              20
# Bright/dry                              20
# Very Light Rain                         20
# Warm + Sunny Cloudy + Windy             20
# Light Showers Inc Some Hail             20
# Dull/damp                               20
# Dry/drizzle                             20
# V.light Rain                            18
# Dry/very Windy                          18
# Slight Drizzle Till End                 18
# Damp - Rain                             17
# V Lt Rain                               16
# Winds Rather Chilly                     16
# Dry (+brief Speels Of Drizzle           16
# A Few Rain Showers                      16
# V Cold Showers                          16
# Cold/showery                            16
# Cold Wind                               16
# Thunder Lightening Rain!                16
# Clear And Dry                           16
# Raining/wet                             16
# Heavy Shower                            16
# Overcast/rain Heavy Showers             16
# Cloud/sun                               16
# Dry (road Wet)                          16
# Dry - Rain                              15
# Some Heavy Showers                      14
# Dark/dry                                14
# Windy Showery                           14
# Dry/dark                                14
# Wet Again                               14
# Wet/light Showers                       12
# Dry/windy/strong Wind                   12
# Cloudy/sun                              12
# V Light Shrs                            12
# Heavy Rain High Winds                   12
# Rain Stopped                            12
# Storm                                   12
# Cloudy Dry                              12
# Foggy Wet                               12
# Dark Cloudy                             12
# V Light Showers                         12
# Intermittent Heavy Showers              12
# Drizzle/wet                             10
# Wet + Dry                               10
# Intermitent Showers                     10
# Dry And Warm                            10
# Sunny + Cloudy                          10
# Rain Shower                             10
# Wet Hail                                10
# Rain & Cloudy                           10
# Wet/cloudy                              10
# Windy/dry                               10
# Wet Rain Stopped                        10
# Cloudy/windy                            10
# Rain/wet                                10
# Wet/stop Raining                        10
# Wet/sunny                               10
# Rain Looking Likely                     10
# Light Shower                             8
# Sun & Clouds                             8
# Wet (spitting)                           8
# Intermittent Showers                     8
# Rain/showers                             8
# Warm + Sunny                             8
# A Few Drops Of Rain                      8
# Dry/wet Road Surface                     8
# Thunder                                  8
# Dry Y                                    8
# Cloudy/drizzle                           8
# Really Wet                               8
# Deluge                                   8
# Dry & Sun                                8
# Wet (windy)                              8
# Wet/thunder                              8
# Dry/gusty                                8
# Sun/Cloudy                               6
# Showers/sunny                            6
# Drizzly Rain                             6
# Fine Drizzle                             6
# Wet Road:sun                             6
# Rain/drizzle                             6
# Drizzle/rain                             6
# Damp/sun                                 6
# Damp/misty/wet                           6
# Drizzle Wet                              6
# S.wet                                    6
# V. Light Rain                            6
# Sun/cloud                                6
# Bright + Cloudy                          6
# L/rain                                   6
# Dark/cloudy                              6
# Cloudy Sun                               6
# Wettish                                  6
# Warm/dry                                 6
# Wetish                                   6
# Very Heavy Rain                          6
# Dry Road Wet With Leaves                 6
# Getting Wet                              6
# wet                                      5
# Getting Dry                              4
# Cloudy + Sunny                           4
# Drizzle/shower                           4
# Heavy Shr                                4
# Sunny Overcast                           4
# Cloudy/showers                           4
# Very Hot                                 4
# Sun Setting                              4
# Intermittent Drizzle                     4
# V. Wet                                   4
# Heavy Downpour/rain                      4
# Cloudy Sunny                             4
# Rain/hail                                4
# Almost Dry                               4
# Very Light Drizzle                       4
# Showers/cloudy                           4
# Windy/drizzle                            4
# Wet (shower)                             4
# X                                        4
# Warm                                     4
# Wet Light Hailstone                      4
# Drizzly                                  4
# Drying Up                                4
# Coldish                                  4
# Hail Stone                               4
# Damp/misty                               4
# Rain/hailstone                           4
# Drizzle/showers                          4
# (drizzle)                                4
# Sunny Cloudy                             4
# Dark Sunny                               4
# Drizzle/cloudy                           4
# S/w                                      4
# Dark Dry                                 4
# Wet T                                    4
# Wetter                                   4
# Snowing                                  4
# Hail                                     4
# Wert                                     2
# (rain After)                             2
# Dy                                       2
# Dark                                     2
# Rain Heavy Showers                       2
# Wet First Then Dry                       2
# No Rain Wet Roads                        2
# H Rain                                   2
# Wetr                                     2
# Ddry                                     2
# Short Hail Shower                        2
# Wetr First Then Dry                      2
# Wet/ Snowing                             2
# Hail Shower                              2
# Rain & Thunder                           2
# Snow!                                    2
# Showers Mix                              2
# V.light Drizzle                          2
# Windy/cloudy                             2
# Cloud/rain                               2
# Wey                                      2
# Drizzle Damp                             2
# Dry With Wet Road                        2
# Wed                                      2
# Wet And Very Windy                       2
# Wet/drizzle                              2
# Shower/wet                               2
# Hailstones                               2
# Dry/mild                                 2
# Sunsetting + Windy                       2
# Too Cold                                 2
# Showers/hailstone                        2
# Drizze                                   2
# Kdry                                     2
# School Out                               2
# Drizzle Rain                             2
# Slight Drizzle/dry                       2
# Dr Ry                                    2
# Mixed                                    2
# Stopped Raining                          2
# Rain Heavy                               2
# Mixed Sunny + Rain                       2
# Drizzle/dry                              2
# Wet/mix                                  2
# Heavy Thunder                            2
# Shower/dry                               2
# Very Hot Dry                             2
# Dry Chill                                2
# Fine Windy                               2
# Druy                                     2
# Cold/cloudy                              2
# Mist                                     2
# Drty                                     2
# Cloudy/rain/sunny                        2
# Fine (windy)                             2
# Road Drying Sun Out                      2
# Dry 3/4 Dry                              2
# Rain Dry                                 2
# Rains                                    2
# Cloudy + Rain                            2
# Partly Sunny                             2
# Dry                         9            2
# Name: Weather, dtype: int64

# %%
# Values for 'Period'
london_all['Period'].value_counts()
# Out:
# Inter-peak (10:00-16:00)       621642
# AM peak (07:00-10:00)          310824
# PM peak (16:00-19:00)          310781
# Evening (19:00-22:00)          310738
# Early Morning (06:00-07:00)    103608
# Name: Period, dtype: int64

# %%
# Values for 'Quarter'
london_all['Quarter'].value_counts()
# Out:
# Q2    857793
# Q3    387926
# Q4    225918
# Q1    182042
# 0      95312
# Name: Quarter, dtype: int64

# %%
# Values for 'Month'
london_all['Month'].value_counts()
# Out:
# 6.0     342097
# 5.0     322130
# 7.0     197446
# 4.0     187294
# 9.0     116110
# 10.0     91949
# 11.0     77933
# 1.0      71934
# 8.0      69880
# 3.0      58696
# 12.0     55862
# 2.0      51936
# Name: Month, dtype: int64

# %%
# Values for 'Year'
london_all['Year'].value_counts()
# Out:
# 19.0    240432
# 18.0    239060
# 17.0    235052
# 16.0    235008
# 15.0    234292
# 21.0    226515
# 20.0    130368
# 14.0    102540
# Name: Year, dtype: int64

# %%
# Values for 'Region'
london_all['Region'].value_counts()
# Out:
# Central London    1048366
# Inner London       615168
# Outer London       375660
# Name: Region, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis - Overall time series

# %%
# Subset data to needed columns
london_all_plot = london_all[["Year", "Total cycles", "Region"]]

# %%
# Remove NA values
london_all_plot_clean = london_all_plot.dropna()

# %%
# Check shape after NA removed
print(london_all.shape)
print(london_all_plot_clean.shape)
# Out:
# (2039194, 22)
# (1643267, 3)

# %%
# All London
sns.set(rc = {'figure.figsize':(25,10)}, font_scale = 12)
sns.set_theme(style="ticks")
y = sns.lineplot(data = london_all_plot, x = 'Year', y = 'Total cycles', hue="Region", ci = None)
y.set_title('Total Cycles per Year in London', fontsize = 30)
y.set_xlabel('Survey Year', fontsize = 20)
y.set_ylabel('Total Cycles', fontsize = 20)
plt.tick_params(axis='both', labelsize=20)

# %%
# Subset data to needed columns
central_london_plot = central_london_clean[["Year", "Total cycles"]]

# %%
# Remove NA values
central_london_plot_clean = central_london_plot.dropna()

# %%
# Check shape after NA removed
print(central_london_clean.shape)
print(central_london_plot_clean.shape)
# Out:
# (1048366, 18)
# (747751, 2)

# %%
# Plot Central London
sns.set(rc = {'figure.figsize':(25,10)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.lineplot(data = central_london_plot_clean, x = 'Year', y = 'Total cycles', color="red", ci = None)
y.set_title('Total Cycles per Year in Central London', fontsize = 30)
y.set_xlabel('Survey Year', fontsize = 20)
y.set_ylabel('Total Cycles', fontsize = 20)
plt.tick_params(axis='both', labelsize=20)

# %%
# Subset data to needed columns
inner_london_plot = inner_london[["Year", "Total cycles"]]

# %%
# Remove na values
inner_london_plot_clean = inner_london.dropna()

# %%
# Plot Inner London
sns.set(rc = {'figure.figsize':(25,10)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.lineplot(data = inner_london_plot_clean, x = 'Year', y = 'Total cycles', color = 'red', ci = None)
y.set_title('Total Cycles per Year in Inner London', fontsize = 30)
y.set_xlabel('Survey Year', fontsize = 20)
y.set_ylabel('Total Cycles', fontsize = 20)
plt.tick_params(axis='both', labelsize=20)

# %%
# Subset data to needed columns
outer_london_plot = outer_london[["Year", "Total cycles"]]

# %%
# Remove na values
outer_london_plot_clean = outer_london.dropna()

# %%
# Plot Outer London
sns.set(rc = {'figure.figsize':(25,10)}, font_scale = 10)
sns.set_theme(style="ticks")
y = sns.lineplot(data = outer_london_plot_clean, x = 'Year', y = 'Total cycles', color = 'red', ci = None)
y.set_title('Total Cycles per Year in Outer London', fontsize = 30)
y.set_xlabel('Survey Year', fontsize = 20)
y.set_ylabel('Total Cycles', fontsize = 20)
plt.tick_params(axis='both', labelsize=20)

# %% [markdown]
# ## Exploratory Data Analysis - Time of Year

# %% [markdown]
# ### Central London

# %%
# Subset to needed columns
central_london_quarter = central_london_clean[["Quarter", "Total cycles"]]

# %%
# Drop na
central_london_quarter_clean = central_london_quarter.dropna()

# %%
# Plot central London by quarter
central_london_chart_quarter = central_london_quarter_clean.groupby(['Quarter']).sum().reset_index()


sns.barplot(x='Quarter', y='Total cycles', data=central_london_chart_quarter)
plt.title('Total cycles by quarter - Central London', fontsize=20)
plt.xlabel('Quarter', fontsize=20)
plt.ylabel('Total cycles', fontsize=20)
plt.ticklabel_format(style='plain', axis='y')

# %%
# Subset to needed columns
central_london_month = central_london_clean[["Month", "Total cycles"]]

# %%
# Drop na
central_london_month_clean = central_london_month.dropna()

# %%
# Plot central London by month
central_london_chart_month = central_london_month_clean.groupby(['Month']).sum().reset_index()

sns.barplot(x='Month', y='Total cycles', data=central_london_chart_month)
plt.title('Total cycles by month - Central London', fontsize=20)
plt.xlabel('Month', fontsize=20)
plt.ylabel('Total cycles', fontsize=20)
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# ### Inner London

# %%
# Subset to needed columns
inner_london_quarter = inner_london[["Quarter", "Total cycles"]]

# %%
# Drop na
inner_london_quarter_clean = inner_london_quarter.dropna()

# %%
# Plot by quarter
inner_london_chart_quarter = inner_london_quarter_clean.groupby(['Quarter']).sum().reset_index()

sns.barplot(x='Quarter', y='Total cycles', data=inner_london_chart_quarter, order=['Q1', 'Q2', 'Q3', 'Q4'])
plt.title('Total cycles by quarter - Inner London', fontsize=20)
plt.xlabel('Quarter', fontsize=20)
plt.ylabel('Total cycles', fontsize=20)
plt.ticklabel_format(style='plain', axis='y')

# %%
# Subset to needed columns
inner_london_month = inner_london[["Month", "Total cycles"]]

# %%
# Drop na
inner_london_month_clean = inner_london_month.dropna()

# %%
# Change month to object
inner_london_month_clean["Month"] = inner_london_month_clean["Month"].astype(object)

# %%
# Plot inner London by month
inner_london_chart_month = inner_london_month_clean.groupby(['Month']).sum().reset_index()

sns.barplot(x='Month', y='Total cycles', data=inner_london_chart_month)
plt.title('Total cycles by month - Inner London', fontsize=20)
plt.xlabel('Month', fontsize=20)
plt.ylabel('Total cycles', fontsize=20)
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# ### Outer London

# %%
# Subset to needed columns
outer_london_quarter = outer_london[["Quarter", "Total cycles"]]

# %%
# Drop na
outer_london_quarter_clean = outer_london_quarter.dropna()

# %%
# Drop values of '0'
outer_london_quarter_clean = outer_london_quarter_clean[outer_london_quarter_clean['Quarter'] != '0']

# %%
# Plot outer London by quarter
outer_london_chart_quarter = outer_london_quarter_clean.groupby(['Quarter']).sum().reset_index()

sns.barplot(x='Quarter', y='Total cycles', data=outer_london_chart_quarter, palette=["sandybrown", "g", "indianred"])
plt.title('Total cycles by quarter - Outer London', fontsize=20)
plt.xlabel('Quarter', fontsize=20)
plt.ylabel('Total cycles', fontsize=20)
plt.ticklabel_format(style='plain', axis='y')

# %%
# Subset to needed columns
outer_london_month = outer_london[["Month", "Total cycles"]]

# %%
# Drop na
outer_london_month_clean = outer_london_month.dropna()

# %%
# Plot outer London by month
outer_london_chart_month = outer_london_month_clean.groupby(['Month']).sum().reset_index()

sns.barplot(x='Month', y='Total cycles', data=outer_london_chart_month)
plt.title('Total cycles by month - Outer London', fontsize=20)
plt.xlabel('Month', fontsize=20)
plt.ylabel('Total cycles', fontsize=20)
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# ### Aggregate

# %%
# Subset to needed columns
london_all_quarter = london_all[["Quarter", "Total cycles", "Region"]]

# %%
# Drop na
london_all_quarter_clean = london_all_quarter.dropna()

# %%
# Drop values of '0'
london_all_quarter_clean = london_all_quarter_clean[london_all_quarter_clean['Quarter'] != '0']

# %%
# Plot all London
london_all_chart_quarter = london_all_quarter_clean.groupby(['Region','Quarter']).sum().reset_index()

sns.barplot(x='Region', y='Total cycles', hue= 'Quarter', data=london_all_chart_quarter)
plt.title('Total cycles by quarter', fontsize=20)
plt.xlabel('Quarter', fontsize=20)
plt.ylabel('Total cycles', fontsize=20)
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# ## Exploratory Data Analysis - Time of Day

# %% [markdown]
# ### Central London

# %%
# Plot
central_london_chart_period = central_london_clean.groupby(['Period']).sum().reset_index()

sns.barplot(x='Period', y='Total cycles', data=central_london_chart_period, order = ['Early Morning (06:00-07:00)',
'AM peak (07:00-10:00)', 'Inter-peak (10:00-16:00)', 'PM peak (16:00-19:00)', 'Evening (19:00-22:00)'])
plt.title('Total cycles by time of day - Central London', fontsize=20)
plt.xlabel('Quarter', fontsize=20)
plt.ylabel('Total cycles', fontsize=20)
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# ### Inner London

# %%
# Plot
inner_london_chart_period = inner_london.groupby(['Period']).sum().reset_index()

sns.barplot(x='Period', y='Total cycles', data=inner_london_chart_period, order = ['Early Morning (06:00-07:00)',
'AM peak (07:00-10:00)', 'Inter-peak (10:00-16:00)', 'PM peak (16:00-19:00)', 'Evening (19:00-22:00)'])
plt.title('Total cycles by time of day - Inner London')
plt.xlabel('Quarter')
plt.ylabel('Total cycles')
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# ### Outer London

# %%
# Plot
outer_london_chart_period = outer_london.groupby(['Period']).sum().reset_index()

sns.barplot(x='Period', y='Total cycles', data=outer_london_chart_period, order = ['Early Morning (06:00-07:00)',
'AM peak (07:00-10:00)', 'Inter-peak (10:00-16:00)', 'PM peak (16:00-19:00)', 'Evening (19:00-22:00)'])
plt.title('Total cycles by time of day - Outer London', fontsize=20)
plt.xlabel('Quarter', fontsize=20)
plt.ylabel('Total cycles', fontsize=20)
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# ### Aggregate

# %%
# Subset to needed columns
london_all_period = london_all[["Period", "Total cycles", "Region"]]

# %%
# Drop na
london_all_period_clean = london_all_period.dropna()

# %%
# Plot
london_all_chart_period = london_all.groupby(['Region','Period']).sum().reset_index()

sns.barplot(x='Region', y='Total cycles', data=london_all_chart_period, hue='Period')
plt.title="Total cycles and time of day"
sns.set(rc={'figure.figsize':(15, 15)})

# %% [markdown]
# ## Exploratory Data Analysis - Weather

# %% [markdown]
# ### Central London

# %%
# Subset data based on top weather conditions
central_london_topweather = central_london_clean.groupby('Weather').filter(lambda x : len(x) > 1000)

# %%
# Examine relationship between total cycles and top weather conditions
sns.barplot(x='Weather', y='Total cycles', data=central_london_topweather, palette = ["red", "blue", "teal", "darkorange", "aquamarine", "grey", "yellow"])
plt.title='Total cycles by Top Weather Conditions - Central London'
plt.xlabel('Weather', fontsize=20)
plt.ylabel('Total cycles', fontsize=20)
plt.tick_params(axis='both', labelsize=20)

# %% [markdown]
# ### Inner London

# %%
# Subset data based on top weather conditions
inner_london_topweather = inner_london.groupby('Weather').filter(lambda x : len(x) > 1000)

# %%
# Drop N/a value
inner_london_topweather = inner_london_topweather[inner_london_topweather['Weather'] != "N/a"]

# %%
# Examine relationship between total cycles and top weather conditions
sns.barplot(x='Weather', y='Total cycles', data=inner_london_topweather, palette=["red", "blue", "yellow", "grey", "teal", "darkorange"])
plt.title='Total cycles by Top Weather Conditions - Inner London'
plt.xlabel('Weather', fontsize=20)
plt.ylabel('Total cycles', fontsize=20)
plt.tick_params(axis='both', labelsize=20)

# %% [markdown]
# ### Outer London

# %%
# Subset data based on top weather conditions
outer_london_topweather = outer_london.groupby('Weather').filter(lambda x : len(x) > 1000)

# %%
# Examine relationship between total cycles and top weather conditions
sns.barplot(x='Weather', y='Total cycles', data=outer_london_topweather, palette=["red", "blue", "yellow", "darkorange"])
plt.title='Total cycles by Top Weather Conditions - Outer London'
plt.xlabel('Weather', fontsize=20)
plt.ylabel('Total cycles', fontsize=20)
plt.tick_params(axis='both', labelsize=20)

# %% [markdown]
# ### Aggregate

# %%
# Subset data based on top weather conditions
all_london_topweather = london_all.groupby('Weather').filter(lambda x : len(x) > 1000)

# %%
# Examine relationship between total cycles and top weather conditions
sns.barplot(x='Weather', y='Total cycles', data=all_london_topweather).set(title="Total cycles by Top Weather Conditions - all London")
# Out:
# [Text(0.5, 1.0, 'Total cycles by Top Weather Conditions - all London')]

# %% [markdown]
# ## Exploratory Data Analysis - Direction of travel

# %% [markdown]
# ### Central London

# %%
# Visualise relationhip between number of cyclists and direction of travel.
central_london_direction = central_london_clean.groupby(['Direction']).sum().reset_index()

fig, ax = plt.subplots()
fig.set_size_inches(15, 8)
ax = sns.barplot(data = central_london_direction, x = 'Direction', y = 'Total cycles')\
.set(title = 'Number of cycles based on travel direction from 2014 to 2022 (Central London)', xlabel = 'Travel direction',
     ylabel = 'Number of Cycles')
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# ### Inner London

# %%
# Visualise relationhip between number of cyclists and direction of travel.
inner_london_direction = inner_london.groupby(['Direction']).sum().reset_index()

fig, ax = plt.subplots()
fig.set_size_inches(15, 8)
ax = sns.barplot(data = inner_london_direction, x = 'Direction', y = 'Total cycles')\
.set(title = 'Number of cycles based on travel direction from 2015 to 2022 (Inner London)', xlabel = 'Travel direction',
     ylabel = 'Number of Cycles')
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# ### Outer London

# %%
# Visualise relationhip between number of cyclists and direction of travel.
outer_london_direction = outer_london.groupby(['Direction']).sum().reset_index()

fig, ax = plt.subplots()
fig.set_size_inches(15, 8)
ax = sns.barplot(data = outer_london_direction, x = 'Direction', y = 'Total cycles')\
.set(title = 'Number of cycles based on travel direction from 2015 to 2022 (Outer London)', xlabel = 'Travel direction',
     ylabel = 'Number of Cycles')
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# ### Aggregate

# %%
# Visualise relationhip between number of cyclists and direction of travel.
london_all_direction = london_all.groupby(['Region','Direction']).sum().reset_index()

fig, ax = plt.subplots()
fig.set_size_inches(15, 8)
ax = sns.barplot(data = london_all_direction, x = 'Region', y = 'Total cycles', hue='Direction')\
.set(title = 'Number of cycles based on travel direction', xlabel = 'Travel direction',
     ylabel = 'Number of Cycles')
plt.ticklabel_format(style='plain', axis='y')
